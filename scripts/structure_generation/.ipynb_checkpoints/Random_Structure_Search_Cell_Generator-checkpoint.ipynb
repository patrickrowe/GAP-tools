# %% [markdown]
# # Code to generate a series of random structures with varying stoichiometries, suitable for RSS.
#
# Examples shown here primarily focus on the elements, C, H and O, but the code readily generalises to any elements.

# %%
from ase import Atom, Atoms, io
import numpy as np
import nglview as nv
import os
import sys

# %%
class boxbuilder:
    
    def __init__(self, dens, stoi, rmin=2.0, name='rss_cell'):
        
        self.stoi = stoi  # a dictionary indicating the number of each element
        if type(self.stoi) == str:
            self.stoi = self.stoi_string_to_dict(self.stoi)
        
        self.dens = dens # a float indicating the target density of the system of interest
        
        self.rmin = rmin
        self.name = name
        self.cell_guess = None
        
        self.mass = self.box_mass_from_stoi()
        self.box_l = self.compute_box_lengths()
        self.atoms_obj = self.gen_empty_box()
        self.populate_box()
        
    def stoi_string_to_dict(self, stoi_string):
        """If the function is passed a string rather than a dictionary, convert it"""
        
        at_temp = Atoms(stoi_string)
        elem = []
        stoi_dict = {}

        # get the unique elements in the cell
        for atom in at_temp:
            if atom.symbol not in elem:
                elem.append(atom.symbol)

        # initialise the dictionary
        for element in elem:
            stoi_dict[element] = 0

        # count atoms of each element into dictionary
        for atom in at_temp:
            stoi_dict[atom.symbol] += 1

        return stoi_dict
        
    def gen_empty_box(self):
        """Generate an empty box for us to put atoms into"""
        
        self.cell_guess = [self.box_l, self.box_l, self.box_l]
        at = Atoms('', positions=[], pbc=True, cell=self.cell_guess)
        return at
        
    def box_mass_from_stoi(self):
        """Computes the mass of the desired cell from the stoichiometry given"""
        
        mass = 0
        
        for elem, num in self.stoi.items():
            atom = Atom(elem, [0, 0, 0])
            mass += atom.mass * num
             
        print(r"Total Box Mass: " + str(mass) + ' g')
        return mass
    
    def compute_box_lengths(self):
        """Compute the box length, assuming a cube, from the mass & density"""
        
        length = (self.mass / self.dens) ** (1/3)
        
        print("Computed ideal box length for dens %f is %f Angstrom" % (self.dens, length))
        
        return length
        
    def populate_box(self):
        mindist_init = self.rmin
        mindist = mindist_init
        nfailed = 1
        
        n_at = 0
        
        for elem, num_el in self.stoi.items():
            n_el = 0
            while n_el < num_el:
                at = Atoms(elem, positions=[[0, 0, 0]], cell=self.cell_guess)

                at.positions[:, 0] += np.random.rand() * self.atoms_obj.get_cell()[0,0]
                at.positions[:, 1] += np.random.rand() * self.atoms_obj.get_cell()[1,1]
                at.positions[:, 2] += np.random.rand() * self.atoms_obj.get_cell()[2,2]

                self.atoms_obj.extend(at)
                
                if n_at == 0:
                    n_at += 1
                    n_el += 1
                    continue
                
                dists = self.atoms_obj.get_distances(-1, np.arange(0, len(self.atoms_obj)-1), mic=True)
                
                if np.array(dists).min() > mindist:
                    #mindist = mindist_init
                    sys.stdout.write('\r')
                    sys.stdout.flush()
                    sys.stdout.write("%s: %i / %i : Minimum distance = %f" % (elem, n_el + 1, num_el, np.array(dists).min()))
                    n_at += 1
                    n_el += 1
                else:
                    del self.atoms_obj[-1]
                    nfailed += 1

                if nfailed % 5000 == 0:
                    mindist -= 0.01
                    print("\n Setting new minimum interatomic distance after many failed placements: " + str(mindist))
                    
    def view_structure(self):
        return nv.show_ase(self.atoms_obj)
    
    def save_struct(self, save_path='./', stoi_in_name=False):
        
        stoi_string = ''
        for elem, n_elem in self.stoi.items():
            stoi_string += str(elem) + str(n_elem)
        
        if stoi_in_name:
            name_full = self.name + '_' + stoi_string
        else:
            name_full = self.name
        
        # Always ends up being useful to just save in a few file formats right from the start
        io.write(os.path.join(save_path, name_full + '.POSCAR'), self.atoms_obj, format='vasp', sort=True)
        io.write(os.path.join(save_path, name_full + '.pdb'), self.atoms_obj, format='proteindatabank')
        io.write(os.path.join(save_path, name_full + '.xyz'), self.atoms_obj, format='extxyz')
        
        # And to save the cell for CP2K
        # a, b, c, al, bet, gam = self.atoms_obj.get_cell_lengths_and_angles()
        # cell = np.array([a, b, c])
        header = np.array([['A', 'B', 'C']])
        cp2k_cell = np.hstack((header.T, self.atoms_obj.cell))
        np.savetxt(os.path.join(save_path, name_full + '.cell'), cp2k_cell, fmt="%s")

# %% [markdown]
# # A quick test example to build a single structure

# %%
# Stoichiometry input can be either in the form of a simple dictionary
test = boxbuilder(1.0, {'C':20, 'H':5, 'O':5})

# Or as a string specifying the chemical formula desired.
test_2 = boxbuilder(1.0, 'C20H5O5')
# Out:
# Total Box Mass: 325.255 g
# Computed ideal box length for dens 1.000000 is 6.877142 Angstrom
# O: 1 / 5 : Minimum distance = 2.05137313
#  Setting new minimum interatomic distance after many failed placements: 1.99
# O: 2 / 5 : Minimum distance = 2.000244
#  Setting new minimum interatomic distance after many failed placements: 1.98
# O: 3 / 5 : Minimum distance = 1.999651
#  Setting new minimum interatomic distance after many failed placements: 1.97
# O: 5 / 5 : Minimum distance = 1.980197Total Box Mass: 325.255 g
# Computed ideal box length for dens 1.000000 is 6.877142 Angstrom
# H: 5 / 5 : Minimum distance = 2.03273113
#  Setting new minimum interatomic distance after many failed placements: 1.99
#
#  Setting new minimum interatomic distance after many failed placements: 1.98
# O: 2 / 5 : Minimum distance = 1.999944
#  Setting new minimum interatomic distance after many failed placements: 1.97
#
#  Setting new minimum interatomic distance after many failed placements: 1.96
#
#  Setting new minimum interatomic distance after many failed placements: 1.95
# O: 3 / 5 : Minimum distance = 1.979614
#  Setting new minimum interatomic distance after many failed placements: 1.94
#
#  Setting new minimum interatomic distance after many failed placements: 1.93
#
#  Setting new minimum interatomic distance after many failed placements: 1.92
# O: 5 / 5 : Minimum distance = 1.923910

# %%
nv.show_ase(test.atoms_obj)
# Out:
# NGLWidget()

# %%
nv.show_ase(test_2.atoms_obj)

# %% [markdown]
# # Bigger 'production run' example. To build several hundred structures with varying stoichiometries.

# %%
def build_stoichiometries():
    """Quick hardcoded helper function to loop over many random stoichiometries"""
    
    
    stoichiometries_other = []
    stoichiometries_h2o = []

    for n_o in np.arange(0,8,1):
        for n_h in np.arange(0,16,2):
            stoi_string = "C100"

            if int(n_o) != 0:
                stoi_string += "O" + str(int(n_o))

            if int(n_h) != 0:
                stoi_string += "H" + str(int(n_h))

            # stoichiometries.append(stoi_string)

            if int(n_o) != 0:
                if int(n_h)/int(n_o) != 2:
                    stoichiometries_other.append(stoi_string)

    for n_o in np.arange(0,52,8):
        for n_h in np.arange(0,52,8):
            stoi_string = "C100"

            if int(n_o) != 0:
                stoi_string += "O" + str(int(n_o))

            if int(n_h) != 0:
                stoi_string += "H" + str(int(n_h))

            # stoichiometries.append(stoi_string)

            if int(n_o) != 0:
                if int(n_h)/int(n_o) != 2:
                    stoichiometries_other.append(stoi_string)

    for n_o in np.arange(0,52,1):
        for n_h in np.arange(0,52,1):
            stoi_string = "C100"

            if int(n_o) != 0:
                stoi_string += "O" + str(int(n_o))

            if int(n_h) != 0:
                stoi_string += "H" + str(int(n_h))

            # stoichiometries.append(stoi_string)

            if int(n_o) != 0:
                if int(n_h)/int(n_o) == 2:
                    stoichiometries_h2o.append(stoi_string)

    return stoichiometries_other, stoichiometries_h2o

# %%
densities = [1.5, 2.0, 2.5]

stoichiometries_other, stoichiometries_h2o = build_stoichiometries()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-58afc02ee2d2> in <module>
#       1 densities = [1.5, 2.0, 2.5]
#       2
# ----> 3 stoichiometries_other, stoichiometries_h2o = build_stoichiometries()
#
# <ipython-input-3-664ca5903ae3> in build_stoichiometries()
#       6     stoichiometries_h2o = []
#       7
# ----> 8     for n_o in np.arange(0,8,1):
#       9         for n_h in np.arange(0,16,2):
#      10             stoi_string = "C100"
#
# NameError: name 'np' is not defined

# %%
if not os.path.exists('./st_other'):
    os.mkdir('./st_other')

for dens in densities:
    if not os.path.exists(os.path.join('./st_other', str(dens))):
        os.mkdir(os.path.join('./st_other', str(dens)))
    for stoi in stoichiometries_other:
        if not os.path.exists(os.path.join('./st_other', str(dens), stoi)):
            os.mkdir(os.path.join('./st_other', str(dens), stoi))
        builder = boxbuilder(dens, stoi)
        builder.save_struct(save_path=os.path.join('./st_other', str(dens), stoi))
# Out:
# Total Box Mass: 1217.099 g
# Computed ideal box length for dens 1.500000 is 9.327062 Angstrom
# C: 62 / 100 : Minimum distance = 2.023540
#  Setting new minimum interatomic distance after many failed placements: 1.99
# C: 64 / 100 : Minimum distance = 2.014975
#  Setting new minimum interatomic distance after many failed placements: 1.98
#
#  Setting new minimum interatomic distance after many failed placements: 1.97
# C: 65 / 100 : Minimum distance = 1.996885
#  Setting new minimum interatomic distance after many failed placements: 1.96
# C: 68 / 100 : Minimum distance = 2.004002
#  Setting new minimum interatomic distance after many failed placements: 1.95
#
#  Setting new minimum interatomic distance after many failed placements: 1.94
#
#  Setting new minimum interatomic distance after many failed placements: 1.93
# C: 70 / 100 : Minimum distance = 1.941527
#  Setting new minimum interatomic distance after many failed placements: 1.92
#
#  Setting new minimum interatomic distance after many failed placements: 1.91
# C: 73 / 100 : Minimum distance = 1.916457
#  Setting new minimum interatomic distance after many failed placements: 1.9
#
#  Setting new minimum interatomic distance after many failed placements: 1.89
# C: 76 / 100 : Minimum distance = 1.894355
#  Setting new minimum interatomic distance after many failed placements: 1.88
# C: 77 / 100 : Minimum distance = 1.957800
#  Setting new minimum interatomic distance after many failed placements: 1.8699999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8599999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8499999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8399999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8299999999999998
# C: 78 / 100 : Minimum distance = 1.831262
#  Setting new minimum interatomic distance after many failed placements: 1.8199999999999998
# C: 79 / 100 : Minimum distance = 1.840833
#  Setting new minimum interatomic distance after many failed placements: 1.8099999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7999999999999998
# C: 81 / 100 : Minimum distance = 1.806431
#  Setting new minimum interatomic distance after many failed placements: 1.7899999999999998
# C: 83 / 100 : Minimum distance = 1.793473
#  Setting new minimum interatomic distance after many failed placements: 1.7799999999999998
# C: 84 / 100 : Minimum distance = 1.843985
#  Setting new minimum interatomic distance after many failed placements: 1.7699999999999998
# C: 87 / 100 : Minimum distance = 1.776292
#  Setting new minimum interatomic distance after many failed placements: 1.7599999999999998
# C: 90 / 100 : Minimum distance = 1.775490
#  Setting new minimum interatomic distance after many failed placements: 1.7499999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7399999999999998
# C: 93 / 100 : Minimum distance = 1.744311
#  Setting new minimum interatomic distance after many failed placements: 1.7299999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7199999999999998
# C: 94 / 100 : Minimum distance = 1.722312
#  Setting new minimum interatomic distance after many failed placements: 1.7099999999999997
# C: 96 / 100 : Minimum distance = 1.733813
#  Setting new minimum interatomic distance after many failed placements: 1.6999999999999997
# C: 97 / 100 : Minimum distance = 1.709104
#  Setting new minimum interatomic distance after many failed placements: 1.6899999999999997
# C: 98 / 100 : Minimum distance = 1.692169
#  Setting new minimum interatomic distance after many failed placements: 1.6799999999999997
# O: 1 / 1 : Minimum distance = 1.710421Total Box Mass: 1221.1309999999999 g
# Computed ideal box length for dens 1.500000 is 9.337351 Angstrom
# C: 67 / 100 : Minimum distance = 2.014532
#  Setting new minimum interatomic distance after many failed placements: 1.99
# C: 70 / 100 : Minimum distance = 2.067870
#  Setting new minimum interatomic distance after many failed placements: 1.98
#
#  Setting new minimum interatomic distance after many failed placements: 1.97
#
#  Setting new minimum interatomic distance after many failed placements: 1.96
#
#  Setting new minimum interatomic distance after many failed placements: 1.95
# C: 72 / 100 : Minimum distance = 1.981600
#  Setting new minimum interatomic distance after many failed placements: 1.94
# C: 74 / 100 : Minimum distance = 1.946154
#  Setting new minimum interatomic distance after many failed placements: 1.93
# C: 75 / 100 : Minimum distance = 1.932423
#  Setting new minimum interatomic distance after many failed placements: 1.92
#
#  Setting new minimum interatomic distance after many failed placements: 1.91
#
#  Setting new minimum interatomic distance after many failed placements: 1.9
# C: 76 / 100 : Minimum distance = 1.965474
#  Setting new minimum interatomic distance after many failed placements: 1.89
#
#  Setting new minimum interatomic distance after many failed placements: 1.88
#
#  Setting new minimum interatomic distance after many failed placements: 1.8699999999999999
# C: 77 / 100 : Minimum distance = 1.901429
#  Setting new minimum interatomic distance after many failed placements: 1.8599999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8499999999999999
# C: 78 / 100 : Minimum distance = 1.917541
#  Setting new minimum interatomic distance after many failed placements: 1.8399999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8299999999999998
# C: 79 / 100 : Minimum distance = 1.839871
#  Setting new minimum interatomic distance after many failed placements: 1.8199999999999998
# C: 81 / 100 : Minimum distance = 1.820254
#  Setting new minimum interatomic distance after many failed placements: 1.8099999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7999999999999998
# C: 83 / 100 : Minimum distance = 1.812459
#  Setting new minimum interatomic distance after many failed placements: 1.7899999999999998
# C: 84 / 100 : Minimum distance = 1.815676
#  Setting new minimum interatomic distance after many failed placements: 1.7799999999999998
# C: 86 / 100 : Minimum distance = 1.782234
#  Setting new minimum interatomic distance after many failed placements: 1.7699999999999998
# C: 87 / 100 : Minimum distance = 1.770673
#  Setting new minimum interatomic distance after many failed placements: 1.7599999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7499999999999998
# C: 89 / 100 : Minimum distance = 1.781156
#  Setting new minimum interatomic distance after many failed placements: 1.7399999999999998
# C: 90 / 100 : Minimum distance = 1.800212
#  Setting new minimum interatomic distance after many failed placements: 1.7299999999999998
# C: 91 / 100 : Minimum distance = 1.747171
#  Setting new minimum interatomic distance after many failed placements: 1.7199999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7099999999999997
# C: 93 / 100 : Minimum distance = 1.759847
#  Setting new minimum interatomic distance after many failed placements: 1.6999999999999997
# C: 94 / 100 : Minimum distance = 1.710422
#  Setting new minimum interatomic distance after many failed placements: 1.6899999999999997
# C: 95 / 100 : Minimum distance = 1.734435
#  Setting new minimum interatomic distance after many failed placements: 1.6799999999999997
# C: 99 / 100 : Minimum distance = 1.691143
#  Setting new minimum interatomic distance after many failed placements: 1.6699999999999997
# O: 1 / 1 : Minimum distance = 1.6803050522
#  Setting new minimum interatomic distance after many failed placements: 1.6599999999999997
# H: 2 / 4 : Minimum distance = 1.722830
#  Setting new minimum interatomic distance after many failed placements: 1.6499999999999997
# H: 4 / 4 : Minimum distance = 1.689493Total Box Mass: 1223.147 g
# Computed ideal box length for dens 1.500000 is 9.342486 Angstrom
# C: 60 / 100 : Minimum distance = 2.026159
#  Setting new minimum interatomic distance after many failed placements: 1.99
# C: 67 / 100 : Minimum distance = 1.993930
#  Setting new minimum interatomic distance after many failed placements: 1.98
# C: 69 / 100 : Minimum distance = 2.047356
#  Setting new minimum interatomic distance after many failed placements: 1.97
#
#  Setting new minimum interatomic distance after many failed placements: 1.96
# C: 70 / 100 : Minimum distance = 1.991047
#  Setting new minimum interatomic distance after many failed placements: 1.95
# C: 71 / 100 : Minimum distance = 1.973895
#  Setting new minimum interatomic distance after many failed placements: 1.94
#
#  Setting new minimum interatomic distance after many failed placements: 1.93
# C: 72 / 100 : Minimum distance = 1.936304
#  Setting new minimum interatomic distance after many failed placements: 1.92
# C: 73 / 100 : Minimum distance = 1.957161
#  Setting new minimum interatomic distance after many failed placements: 1.91
# C: 74 / 100 : Minimum distance = 1.912597
#  Setting new minimum interatomic distance after many failed placements: 1.9
# C: 75 / 100 : Minimum distance = 1.914449
#  Setting new minimum interatomic distance after many failed placements: 1.89
#
#  Setting new minimum interatomic distance after many failed placements: 1.88
# C: 77 / 100 : Minimum distance = 1.893601
#  Setting new minimum interatomic distance after many failed placements: 1.8699999999999999
# C: 78 / 100 : Minimum distance = 1.895116
#  Setting new minimum interatomic distance after many failed placements: 1.8599999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8499999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8399999999999999
# C: 79 / 100 : Minimum distance = 1.843472
#  Setting new minimum interatomic distance after many failed placements: 1.8299999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.8199999999999998
# C: 81 / 100 : Minimum distance = 1.821385
#  Setting new minimum interatomic distance after many failed placements: 1.8099999999999998
# C: 83 / 100 : Minimum distance = 1.839320
#  Setting new minimum interatomic distance after many failed placements: 1.7999999999999998
# C: 84 / 100 : Minimum distance = 1.813818
#  Setting new minimum interatomic distance after many failed placements: 1.7899999999999998
# C: 86 / 100 : Minimum distance = 1.839218
#  Setting new minimum interatomic distance after many failed placements: 1.7799999999999998
# C: 88 / 100 : Minimum distance = 1.846194
#  Setting new minimum interatomic distance after many failed placements: 1.7699999999999998
# C: 90 / 100 : Minimum distance = 1.771205
#  Setting new minimum interatomic distance after many failed placements: 1.7599999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7499999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7399999999999998
# C: 93 / 100 : Minimum distance = 1.773029
#  Setting new minimum interatomic distance after many failed placements: 1.7299999999999998
# C: 96 / 100 : Minimum distance = 1.761322
#  Setting new minimum interatomic distance after many failed placements: 1.7199999999999998
# C: 98 / 100 : Minimum distance = 1.738903
#  Setting new minimum interatomic distance after many failed placements: 1.7099999999999997
# C: 100 / 100 : Minimum distance = 1.714570
#  Setting new minimum interatomic distance after many failed placements: 1.6999999999999997
# O: 1 / 1 : Minimum distance = 1.702623
#  Setting new minimum interatomic distance after many failed placements: 1.6899999999999997
# H: 1 / 6 : Minimum distance = 1.692277
#  Setting new minimum interatomic distance after many failed placements: 1.6799999999999997
# H: 2 / 6 : Minimum distance = 1.705568
#  Setting new minimum interatomic distance after many failed placements: 1.6699999999999997
# H: 5 / 6 : Minimum distance = 1.710033
#  Setting new minimum interatomic distance after many failed placements: 1.6599999999999997
# H: 6 / 6 : Minimum distance = 1.683202Total Box Mass: 1225.163 g
# Computed ideal box length for dens 1.500000 is 9.347616 Angstrom
# C: 65 / 100 : Minimum distance = 2.022715
#  Setting new minimum interatomic distance after many failed placements: 1.99
# C: 66 / 100 : Minimum distance = 2.075456
#  Setting new minimum interatomic distance after many failed placements: 1.98
# C: 67 / 100 : Minimum distance = 2.053302
#  Setting new minimum interatomic distance after many failed placements: 1.97
# C: 68 / 100 : Minimum distance = 2.024991
#  Setting new minimum interatomic distance after many failed placements: 1.96
# C: 69 / 100 : Minimum distance = 1.965185
#  Setting new minimum interatomic distance after many failed placements: 1.95
# C: 70 / 100 : Minimum distance = 1.960917
#  Setting new minimum interatomic distance after many failed placements: 1.94
# C: 71 / 100 : Minimum distance = 1.953511
#  Setting new minimum interatomic distance after many failed placements: 1.93
# C: 75 / 100 : Minimum distance = 1.940779
#  Setting new minimum interatomic distance after many failed placements: 1.92
#
#  Setting new minimum interatomic distance after many failed placements: 1.91
#
#  Setting new minimum interatomic distance after many failed placements: 1.9
#
#  Setting new minimum interatomic distance after many failed placements: 1.89
#
#  Setting new minimum interatomic distance after many failed placements: 1.88
# C: 77 / 100 : Minimum distance = 1.915019
#  Setting new minimum interatomic distance after many failed placements: 1.8699999999999999
# C: 79 / 100 : Minimum distance = 1.892633
#  Setting new minimum interatomic distance after many failed placements: 1.8599999999999999
# C: 81 / 100 : Minimum distance = 1.868222
#  Setting new minimum interatomic distance after many failed placements: 1.8499999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8399999999999999
# C: 84 / 100 : Minimum distance = 1.862313
#  Setting new minimum interatomic distance after many failed placements: 1.8299999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.8199999999999998
# C: 85 / 100 : Minimum distance = 1.845311
#  Setting new minimum interatomic distance after many failed placements: 1.8099999999999998
# C: 88 / 100 : Minimum distance = 1.896232
#  Setting new minimum interatomic distance after many failed placements: 1.7999999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7899999999999998
# C: 89 / 100 : Minimum distance = 1.822683
#  Setting new minimum interatomic distance after many failed placements: 1.7799999999999998
# C: 91 / 100 : Minimum distance = 1.782087
#  Setting new minimum interatomic distance after many failed placements: 1.7699999999999998
# C: 92 / 100 : Minimum distance = 1.786919
#  Setting new minimum interatomic distance after many failed placements: 1.7599999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7499999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7399999999999998
# C: 93 / 100 : Minimum distance = 1.760485
#  Setting new minimum interatomic distance after many failed placements: 1.7299999999999998
# C: 94 / 100 : Minimum distance = 1.730364
#  Setting new minimum interatomic distance after many failed placements: 1.7199999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7099999999999997
# C: 96 / 100 : Minimum distance = 1.741620
#  Setting new minimum interatomic distance after many failed placements: 1.6999999999999997
# C: 97 / 100 : Minimum distance = 1.703549
#  Setting new minimum interatomic distance after many failed placements: 1.6899999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6799999999999997
# C: 98 / 100 : Minimum distance = 1.682158
#  Setting new minimum interatomic distance after many failed placements: 1.6699999999999997
# C: 100 / 100 : Minimum distance = 1.751525
#  Setting new minimum interatomic distance after many failed placements: 1.6599999999999997
# H: 1 / 8 : Minimum distance = 1.701402
#  Setting new minimum interatomic distance after many failed placements: 1.6499999999999997
# H: 2 / 8 : Minimum distance = 1.659187
#  Setting new minimum interatomic distance after many failed placements: 1.6399999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6299999999999997
# H: 4 / 8 : Minimum distance = 1.638843
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999997
# H: 8 / 8 : Minimum distance = 1.631475Total Box Mass: 1227.1789999999999 g
# Computed ideal box length for dens 1.500000 is 9.352741 Angstrom
# C: 64 / 100 : Minimum distance = 2.007662
#  Setting new minimum interatomic distance after many failed placements: 1.99
# C: 66 / 100 : Minimum distance = 2.072823
#  Setting new minimum interatomic distance after many failed placements: 1.98
# C: 67 / 100 : Minimum distance = 2.007271
#  Setting new minimum interatomic distance after many failed placements: 1.97
# C: 68 / 100 : Minimum distance = 1.973489
#  Setting new minimum interatomic distance after many failed placements: 1.96
#
#  Setting new minimum interatomic distance after many failed placements: 1.95
# C: 70 / 100 : Minimum distance = 1.971001
#  Setting new minimum interatomic distance after many failed placements: 1.94
# C: 71 / 100 : Minimum distance = 1.961158
#  Setting new minimum interatomic distance after many failed placements: 1.93
#
#  Setting new minimum interatomic distance after many failed placements: 1.92
# C: 73 / 100 : Minimum distance = 1.926979
#  Setting new minimum interatomic distance after many failed placements: 1.91
#
#  Setting new minimum interatomic distance after many failed placements: 1.9
# C: 74 / 100 : Minimum distance = 1.911173
#  Setting new minimum interatomic distance after many failed placements: 1.89
#
#  Setting new minimum interatomic distance after many failed placements: 1.88
#
#  Setting new minimum interatomic distance after many failed placements: 1.8699999999999999
# C: 75 / 100 : Minimum distance = 1.938089
#  Setting new minimum interatomic distance after many failed placements: 1.8599999999999999
# C: 78 / 100 : Minimum distance = 1.934773
#  Setting new minimum interatomic distance after many failed placements: 1.8499999999999999
# C: 79 / 100 : Minimum distance = 1.888234
#  Setting new minimum interatomic distance after many failed placements: 1.8399999999999999
# C: 80 / 100 : Minimum distance = 1.866366
#  Setting new minimum interatomic distance after many failed placements: 1.8299999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.8199999999999998
# C: 81 / 100 : Minimum distance = 1.830951
#  Setting new minimum interatomic distance after many failed placements: 1.8099999999999998
# C: 83 / 100 : Minimum distance = 1.814916
#  Setting new minimum interatomic distance after many failed placements: 1.7999999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7899999999999998
# C: 84 / 100 : Minimum distance = 1.793684
#  Setting new minimum interatomic distance after many failed placements: 1.7799999999999998
# C: 87 / 100 : Minimum distance = 1.795176
#  Setting new minimum interatomic distance after many failed placements: 1.7699999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7599999999999998
# C: 89 / 100 : Minimum distance = 1.766670
#  Setting new minimum interatomic distance after many failed placements: 1.7499999999999998
# C: 92 / 100 : Minimum distance = 1.765859
#  Setting new minimum interatomic distance after many failed placements: 1.7399999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7299999999999998
# C: 95 / 100 : Minimum distance = 1.730573
#  Setting new minimum interatomic distance after many failed placements: 1.7199999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7099999999999997
# C: 97 / 100 : Minimum distance = 1.710658
#  Setting new minimum interatomic distance after many failed placements: 1.6999999999999997
# C: 98 / 100 : Minimum distance = 1.702806
#  Setting new minimum interatomic distance after many failed placements: 1.6899999999999997
# C: 99 / 100 : Minimum distance = 1.697773
#  Setting new minimum interatomic distance after many failed placements: 1.6799999999999997
# H: 1 / 10 : Minimum distance = 1.728471990
#  Setting new minimum interatomic distance after many failed placements: 1.6699999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6599999999999997
# H: 3 / 10 : Minimum distance = 1.665884
#  Setting new minimum interatomic distance after many failed placements: 1.6499999999999997
# H: 4 / 10 : Minimum distance = 1.751321
#  Setting new minimum interatomic distance after many failed placements: 1.6399999999999997
# H: 6 / 10 : Minimum distance = 1.648837
#  Setting new minimum interatomic distance after many failed placements: 1.6299999999999997
# H: 10 / 10 : Minimum distance = 1.669584Total Box Mass: 1229.195 g
# Computed ideal box length for dens 1.500000 is 9.357859 Angstrom
# C: 61 / 100 : Minimum distance = 2.011317
#  Setting new minimum interatomic distance after many failed placements: 1.99
# C: 63 / 100 : Minimum distance = 2.025643
#  Setting new minimum interatomic distance after many failed placements: 1.98
# C: 64 / 100 : Minimum distance = 2.056287
#  Setting new minimum interatomic distance after many failed placements: 1.97
# C: 66 / 100 : Minimum distance = 1.977574
#  Setting new minimum interatomic distance after many failed placements: 1.96
# C: 67 / 100 : Minimum distance = 2.017290
#  Setting new minimum interatomic distance after many failed placements: 1.95
# C: 68 / 100 : Minimum distance = 1.985294
#  Setting new minimum interatomic distance after many failed placements: 1.94
# C: 69 / 100 : Minimum distance = 1.958455
#  Setting new minimum interatomic distance after many failed placements: 1.93
# C: 73 / 100 : Minimum distance = 1.947395
#  Setting new minimum interatomic distance after many failed placements: 1.92
#
#  Setting new minimum interatomic distance after many failed placements: 1.91
#
#  Setting new minimum interatomic distance after many failed placements: 1.9
# C: 74 / 100 : Minimum distance = 1.924838
#  Setting new minimum interatomic distance after many failed placements: 1.89
# C: 75 / 100 : Minimum distance = 1.909213
#  Setting new minimum interatomic distance after many failed placements: 1.88
#
#  Setting new minimum interatomic distance after many failed placements: 1.8699999999999999
# C: 76 / 100 : Minimum distance = 1.937897
#  Setting new minimum interatomic distance after many failed placements: 1.8599999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8499999999999999
# C: 81 / 100 : Minimum distance = 1.850939
#  Setting new minimum interatomic distance after many failed placements: 1.8399999999999999
# C: 82 / 100 : Minimum distance = 1.855040
#  Setting new minimum interatomic distance after many failed placements: 1.8299999999999998
# C: 85 / 100 : Minimum distance = 1.849068
#  Setting new minimum interatomic distance after many failed placements: 1.8199999999999998
# C: 86 / 100 : Minimum distance = 1.839766
#  Setting new minimum interatomic distance after many failed placements: 1.8099999999999998
# C: 87 / 100 : Minimum distance = 1.839379
#  Setting new minimum interatomic distance after many failed placements: 1.7999999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7899999999999998
# C: 89 / 100 : Minimum distance = 1.814894
#  Setting new minimum interatomic distance after many failed placements: 1.7799999999999998
# C: 91 / 100 : Minimum distance = 1.791714
#  Setting new minimum interatomic distance after many failed placements: 1.7699999999999998
# C: 92 / 100 : Minimum distance = 1.841590
#  Setting new minimum interatomic distance after many failed placements: 1.7599999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7499999999999998
# C: 93 / 100 : Minimum distance = 1.753491
#  Setting new minimum interatomic distance after many failed placements: 1.7399999999999998
# C: 94 / 100 : Minimum distance = 1.810622
#  Setting new minimum interatomic distance after many failed placements: 1.7299999999999998
# C: 95 / 100 : Minimum distance = 1.795317
#  Setting new minimum interatomic distance after many failed placements: 1.7199999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7099999999999997
# C: 99 / 100 : Minimum distance = 1.727752
#  Setting new minimum interatomic distance after many failed placements: 1.6999999999999997
# O: 1 / 1 : Minimum distance = 1.7085334985
#  Setting new minimum interatomic distance after many failed placements: 1.6899999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6799999999999997
# H: 1 / 12 : Minimum distance = 1.708372
#  Setting new minimum interatomic distance after many failed placements: 1.6699999999999997
# H: 3 / 12 : Minimum distance = 1.730889
#  Setting new minimum interatomic distance after many failed placements: 1.6599999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6499999999999997
# H: 5 / 12 : Minimum distance = 1.672511
#  Setting new minimum interatomic distance after many failed placements: 1.6399999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6299999999999997
# H: 7 / 12 : Minimum distance = 1.641912
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999997
# H: 8 / 12 : Minimum distance = 1.657115
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999997
# H: 11 / 12 : Minimum distance = 1.621930
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999996
# H: 12 / 12 : Minimum distance = 1.633854Total Box Mass: 1231.211 g
# Computed ideal box length for dens 1.500000 is 9.362972 Angstrom
# C: 64 / 100 : Minimum distance = 2.002705
#  Setting new minimum interatomic distance after many failed placements: 1.99
# C: 66 / 100 : Minimum distance = 2.001922
#  Setting new minimum interatomic distance after many failed placements: 1.98
#
#  Setting new minimum interatomic distance after many failed placements: 1.97
# C: 68 / 100 : Minimum distance = 1.988337
#  Setting new minimum interatomic distance after many failed placements: 1.96
# C: 69 / 100 : Minimum distance = 1.960125
#  Setting new minimum interatomic distance after many failed placements: 1.95
#
#  Setting new minimum interatomic distance after many failed placements: 1.94
# C: 71 / 100 : Minimum distance = 1.961215
#  Setting new minimum interatomic distance after many failed placements: 1.93
#
#  Setting new minimum interatomic distance after many failed placements: 1.92
# C: 72 / 100 : Minimum distance = 1.938275
#  Setting new minimum interatomic distance after many failed placements: 1.91
#
#  Setting new minimum interatomic distance after many failed placements: 1.9
# C: 73 / 100 : Minimum distance = 1.902072
#  Setting new minimum interatomic distance after many failed placements: 1.89
# C: 74 / 100 : Minimum distance = 1.904296
#  Setting new minimum interatomic distance after many failed placements: 1.88
# C: 75 / 100 : Minimum distance = 1.883569
#  Setting new minimum interatomic distance after many failed placements: 1.8699999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8599999999999999
# C: 77 / 100 : Minimum distance = 1.864708
#  Setting new minimum interatomic distance after many failed placements: 1.8499999999999999
# C: 78 / 100 : Minimum distance = 1.874743
#  Setting new minimum interatomic distance after many failed placements: 1.8399999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8299999999999998
# C: 80 / 100 : Minimum distance = 1.842012
#  Setting new minimum interatomic distance after many failed placements: 1.8199999999999998
# C: 82 / 100 : Minimum distance = 1.883606
#  Setting new minimum interatomic distance after many failed placements: 1.8099999999999998
# C: 83 / 100 : Minimum distance = 1.820762
#  Setting new minimum interatomic distance after many failed placements: 1.7999999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7899999999999998
# C: 84 / 100 : Minimum distance = 1.794953
#  Setting new minimum interatomic distance after many failed placements: 1.7799999999999998
# C: 86 / 100 : Minimum distance = 1.819897
#  Setting new minimum interatomic distance after many failed placements: 1.7699999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7599999999999998
# C: 87 / 100 : Minimum distance = 1.778598
#  Setting new minimum interatomic distance after many failed placements: 1.7499999999999998
# C: 89 / 100 : Minimum distance = 1.770200
#  Setting new minimum interatomic distance after many failed placements: 1.7399999999999998
# C: 91 / 100 : Minimum distance = 1.759115
#  Setting new minimum interatomic distance after many failed placements: 1.7299999999999998
# C: 93 / 100 : Minimum distance = 1.735211
#  Setting new minimum interatomic distance after many failed placements: 1.7199999999999998
# C: 94 / 100 : Minimum distance = 1.738173
#  Setting new minimum interatomic distance after many failed placements: 1.7099999999999997
# C: 95 / 100 : Minimum distance = 1.732730
#  Setting new minimum interatomic distance after many failed placements: 1.6999999999999997
# C: 96 / 100 : Minimum distance = 1.725492
#  Setting new minimum interatomic distance after many failed placements: 1.6899999999999997
# C: 100 / 100 : Minimum distance = 1.696688
#  Setting new minimum interatomic distance after many failed placements: 1.6799999999999997
# H: 2 / 14 : Minimum distance = 1.683103
#  Setting new minimum interatomic distance after many failed placements: 1.6699999999999997
# H: 4 / 14 : Minimum distance = 1.717094
#  Setting new minimum interatomic distance after many failed placements: 1.6599999999999997
# H: 7 / 14 : Minimum distance = 1.670066
#  Setting new minimum interatomic distance after many failed placements: 1.6499999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6399999999999997
# H: 13 / 14 : Minimum distance = 1.653310
#  Setting new minimum interatomic distance after many failed placements: 1.6299999999999997
# H: 14 / 14 : Minimum distance = 1.665562Total Box Mass: 1233.098 g
# Computed ideal box length for dens 1.500000 is 9.367753 Angstrom
# C: 61 / 100 : Minimum distance = 2.088167
#  Setting new minimum interatomic distance after many failed placements: 1.99
# C: 66 / 100 : Minimum distance = 2.047688
#  Setting new minimum interatomic distance after many failed placements: 1.98
# C: 67 / 100 : Minimum distance = 1.994138
#  Setting new minimum interatomic distance after many failed placements: 1.97
# C: 69 / 100 : Minimum distance = 2.001583
#  Setting new minimum interatomic distance after many failed placements: 1.96
# C: 70 / 100 : Minimum distance = 1.978529
#  Setting new minimum interatomic distance after many failed placements: 1.95
#
#  Setting new minimum interatomic distance after many failed placements: 1.94
# C: 71 / 100 : Minimum distance = 1.953116
#  Setting new minimum interatomic distance after many failed placements: 1.93
#
#  Setting new minimum interatomic distance after many failed placements: 1.92
#
#  Setting new minimum interatomic distance after many failed placements: 1.91
#
#  Setting new minimum interatomic distance after many failed placements: 1.9
# C: 74 / 100 : Minimum distance = 1.944528
#  Setting new minimum interatomic distance after many failed placements: 1.89
# C: 76 / 100 : Minimum distance = 1.901795
#  Setting new minimum interatomic distance after many failed placements: 1.88
#
#  Setting new minimum interatomic distance after many failed placements: 1.8699999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8599999999999999
# C: 78 / 100 : Minimum distance = 1.884455
#  Setting new minimum interatomic distance after many failed placements: 1.8499999999999999
# C: 80 / 100 : Minimum distance = 1.853590
#  Setting new minimum interatomic distance after many failed placements: 1.8399999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8299999999999998
# C: 82 / 100 : Minimum distance = 1.869417
#  Setting new minimum interatomic distance after many failed placements: 1.8199999999999998
# C: 83 / 100 : Minimum distance = 1.822987
#  Setting new minimum interatomic distance after many failed placements: 1.8099999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7999999999999998
# C: 84 / 100 : Minimum distance = 1.841753
#  Setting new minimum interatomic distance after many failed placements: 1.7899999999999998
# C: 85 / 100 : Minimum distance = 1.802687
#  Setting new minimum interatomic distance after many failed placements: 1.7799999999999998
# C: 86 / 100 : Minimum distance = 1.798732
#  Setting new minimum interatomic distance after many failed placements: 1.7699999999999998
# C: 89 / 100 : Minimum distance = 1.801826
#  Setting new minimum interatomic distance after many failed placements: 1.7599999999999998
# C: 91 / 100 : Minimum distance = 1.793145
#  Setting new minimum interatomic distance after many failed placements: 1.7499999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7399999999999998
# C: 92 / 100 : Minimum distance = 1.759110
#  Setting new minimum interatomic distance after many failed placements: 1.7299999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7199999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7099999999999997
# C: 94 / 100 : Minimum distance = 1.732297
#  Setting new minimum interatomic distance after many failed placements: 1.6999999999999997
# C: 95 / 100 : Minimum distance = 1.718512
#  Setting new minimum interatomic distance after many failed placements: 1.6899999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6799999999999997
# C: 96 / 100 : Minimum distance = 1.749136
#  Setting new minimum interatomic distance after many failed placements: 1.6699999999999997
# C: 99 / 100 : Minimum distance = 1.672880
#  Setting new minimum interatomic distance after many failed placements: 1.6599999999999997
# O: 2 / 2 : Minimum distance = 1.699883Total Box Mass: 1235.114 g
# Computed ideal box length for dens 1.500000 is 9.372856 Angstrom
# C: 64 / 100 : Minimum distance = 2.032697
#  Setting new minimum interatomic distance after many failed placements: 1.99
# C: 69 / 100 : Minimum distance = 2.016705
#  Setting new minimum interatomic distance after many failed placements: 1.98
#
#  Setting new minimum interatomic distance after many failed placements: 1.97
# C: 70 / 100 : Minimum distance = 1.994946
#  Setting new minimum interatomic distance after many failed placements: 1.96
#
#  Setting new minimum interatomic distance after many failed placements: 1.95
#
#  Setting new minimum interatomic distance after many failed placements: 1.94
#
#  Setting new minimum interatomic distance after many failed placements: 1.93
# C: 72 / 100 : Minimum distance = 1.944912
#  Setting new minimum interatomic distance after many failed placements: 1.92
#
#  Setting new minimum interatomic distance after many failed placements: 1.91
# C: 74 / 100 : Minimum distance = 1.961102
#  Setting new minimum interatomic distance after many failed placements: 1.9
#
#  Setting new minimum interatomic distance after many failed placements: 1.89
# C: 75 / 100 : Minimum distance = 1.904944
#  Setting new minimum interatomic distance after many failed placements: 1.88
#
#  Setting new minimum interatomic distance after many failed placements: 1.8699999999999999
# C: 77 / 100 : Minimum distance = 1.939351
#  Setting new minimum interatomic distance after many failed placements: 1.8599999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8499999999999999
# C: 78 / 100 : Minimum distance = 1.861195
#  Setting new minimum interatomic distance after many failed placements: 1.8399999999999999
# C: 80 / 100 : Minimum distance = 1.886360
#  Setting new minimum interatomic distance after many failed placements: 1.8299999999999998
# C: 81 / 100 : Minimum distance = 1.850523
#  Setting new minimum interatomic distance after many failed placements: 1.8199999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.8099999999999998
# C: 83 / 100 : Minimum distance = 1.849312
#  Setting new minimum interatomic distance after many failed placements: 1.7999999999999998
# C: 85 / 100 : Minimum distance = 1.837201
#  Setting new minimum interatomic distance after many failed placements: 1.7899999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7799999999999998
# C: 88 / 100 : Minimum distance = 1.800763
#  Setting new minimum interatomic distance after many failed placements: 1.7699999999999998
# C: 89 / 100 : Minimum distance = 1.771089
#  Setting new minimum interatomic distance after many failed placements: 1.7599999999999998
# C: 90 / 100 : Minimum distance = 1.814572
#  Setting new minimum interatomic distance after many failed placements: 1.7499999999999998
# C: 91 / 100 : Minimum distance = 1.750715
#  Setting new minimum interatomic distance after many failed placements: 1.7399999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7299999999999998
# C: 95 / 100 : Minimum distance = 1.824252
#  Setting new minimum interatomic distance after many failed placements: 1.7199999999999998
# C: 100 / 100 : Minimum distance = 1.735343
#  Setting new minimum interatomic distance after many failed placements: 1.7099999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6999999999999997
# H: 2 / 2 : Minimum distance = 1.721230Total Box Mass: 1239.146 g
# Computed ideal box length for dens 1.500000 is 9.383044 Angstrom
# C: 63 / 100 : Minimum distance = 2.084957
#  Setting new minimum interatomic distance after many failed placements: 1.99
# C: 64 / 100 : Minimum distance = 2.051013
#  Setting new minimum interatomic distance after many failed placements: 1.98
# C: 67 / 100 : Minimum distance = 1.982715
#  Setting new minimum interatomic distance after many failed placements: 1.97
#
#  Setting new minimum interatomic distance after many failed placements: 1.96
# C: 68 / 100 : Minimum distance = 2.002713
#  Setting new minimum interatomic distance after many failed placements: 1.95
#
#  Setting new minimum interatomic distance after many failed placements: 1.94
# C: 70 / 100 : Minimum distance = 1.967654
#  Setting new minimum interatomic distance after many failed placements: 1.93
#
#  Setting new minimum interatomic distance after many failed placements: 1.92
#
#  Setting new minimum interatomic distance after many failed placements: 1.91
# C: 72 / 100 : Minimum distance = 1.912202
#  Setting new minimum interatomic distance after many failed placements: 1.9
# C: 74 / 100 : Minimum distance = 1.932598
#  Setting new minimum interatomic distance after many failed placements: 1.89
# C: 75 / 100 : Minimum distance = 1.930850
#  Setting new minimum interatomic distance after many failed placements: 1.88
# C: 76 / 100 : Minimum distance = 1.882627
#  Setting new minimum interatomic distance after many failed placements: 1.8699999999999999
# C: 77 / 100 : Minimum distance = 1.902888
#  Setting new minimum interatomic distance after many failed placements: 1.8599999999999999
# C: 79 / 100 : Minimum distance = 1.928024
#  Setting new minimum interatomic distance after many failed placements: 1.8499999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8399999999999999
# C: 81 / 100 : Minimum distance = 1.849145
#  Setting new minimum interatomic distance after many failed placements: 1.8299999999999998
# C: 83 / 100 : Minimum distance = 1.831812
#  Setting new minimum interatomic distance after many failed placements: 1.8199999999999998
# C: 84 / 100 : Minimum distance = 1.821649
#  Setting new minimum interatomic distance after many failed placements: 1.8099999999999998
# C: 87 / 100 : Minimum distance = 1.860572
#  Setting new minimum interatomic distance after many failed placements: 1.7999999999999998
# C: 89 / 100 : Minimum distance = 1.815342
#  Setting new minimum interatomic distance after many failed placements: 1.7899999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7799999999999998
# C: 90 / 100 : Minimum distance = 1.806950
#  Setting new minimum interatomic distance after many failed placements: 1.7699999999999998
# C: 92 / 100 : Minimum distance = 1.775395
#  Setting new minimum interatomic distance after many failed placements: 1.7599999999999998
# C: 93 / 100 : Minimum distance = 1.800686
#  Setting new minimum interatomic distance after many failed placements: 1.7499999999999998
# C: 95 / 100 : Minimum distance = 1.797245
#  Setting new minimum interatomic distance after many failed placements: 1.7399999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7299999999999998
# C: 96 / 100 : Minimum distance = 1.792699
#  Setting new minimum interatomic distance after many failed placements: 1.7199999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7099999999999997
# C: 97 / 100 : Minimum distance = 1.773281
#  Setting new minimum interatomic distance after many failed placements: 1.6999999999999997
# C: 100 / 100 : Minimum distance = 1.716028
#  Setting new minimum interatomic distance after many failed placements: 1.6899999999999997
# H: 1 / 6 : Minimum distance = 1.722802
#  Setting new minimum interatomic distance after many failed placements: 1.6799999999999997
# H: 2 / 6 : Minimum distance = 1.703512
#  Setting new minimum interatomic distance after many failed placements: 1.6699999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6599999999999997
# H: 5 / 6 : Minimum distance = 1.671146
#  Setting new minimum interatomic distance after many failed placements: 1.6499999999999997
# H: 6 / 6 : Minimum distance = 1.663378Total Box Mass: 1241.162 g
# Computed ideal box length for dens 1.500000 is 9.388129 Angstrom
# C: 64 / 100 : Minimum distance = 2.080757
#  Setting new minimum interatomic distance after many failed placements: 1.99
# C: 68 / 100 : Minimum distance = 2.043681
#  Setting new minimum interatomic distance after many failed placements: 1.98
# C: 69 / 100 : Minimum distance = 2.000507
#  Setting new minimum interatomic distance after many failed placements: 1.97
# C: 71 / 100 : Minimum distance = 1.971480
#  Setting new minimum interatomic distance after many failed placements: 1.96
#
#  Setting new minimum interatomic distance after many failed placements: 1.95
# C: 72 / 100 : Minimum distance = 1.979966
#  Setting new minimum interatomic distance after many failed placements: 1.94
# C: 73 / 100 : Minimum distance = 1.966486
#  Setting new minimum interatomic distance after many failed placements: 1.93
#
#  Setting new minimum interatomic distance after many failed placements: 1.92
#
#  Setting new minimum interatomic distance after many failed placements: 1.91
# C: 74 / 100 : Minimum distance = 1.983827
#  Setting new minimum interatomic distance after many failed placements: 1.9
#
#  Setting new minimum interatomic distance after many failed placements: 1.89
#
#  Setting new minimum interatomic distance after many failed placements: 1.88
#
#  Setting new minimum interatomic distance after many failed placements: 1.8699999999999999
# C: 76 / 100 : Minimum distance = 1.919896
#  Setting new minimum interatomic distance after many failed placements: 1.8599999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8499999999999999
# C: 79 / 100 : Minimum distance = 1.853630
#  Setting new minimum interatomic distance after many failed placements: 1.8399999999999999
# C: 81 / 100 : Minimum distance = 1.844428
#  Setting new minimum interatomic distance after many failed placements: 1.8299999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.8199999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.8099999999999998
# C: 82 / 100 : Minimum distance = 1.846284
#  Setting new minimum interatomic distance after many failed placements: 1.7999999999999998
# C: 84 / 100 : Minimum distance = 1.815645
#  Setting new minimum interatomic distance after many failed placements: 1.7899999999999998
# C: 85 / 100 : Minimum distance = 1.863674
#  Setting new minimum interatomic distance after many failed placements: 1.7799999999999998
# C: 86 / 100 : Minimum distance = 1.820814
#  Setting new minimum interatomic distance after many failed placements: 1.7699999999999998
# C: 87 / 100 : Minimum distance = 1.826283
#  Setting new minimum interatomic distance after many failed placements: 1.7599999999999998
# C: 88 / 100 : Minimum distance = 1.769396
#  Setting new minimum interatomic distance after many failed placements: 1.7499999999999998
# C: 90 / 100 : Minimum distance = 1.764480
#  Setting new minimum interatomic distance after many failed placements: 1.7399999999999998
# C: 93 / 100 : Minimum distance = 1.757102
#  Setting new minimum interatomic distance after many failed placements: 1.7299999999999998
# C: 96 / 100 : Minimum distance = 1.743207
#  Setting new minimum interatomic distance after many failed placements: 1.7199999999999998
# C: 97 / 100 : Minimum distance = 1.758771
#  Setting new minimum interatomic distance after many failed placements: 1.7099999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6999999999999997
# C: 98 / 100 : Minimum distance = 1.708728
#  Setting new minimum interatomic distance after many failed placements: 1.6899999999999997
# C: 99 / 100 : Minimum distance = 1.703849
#  Setting new minimum interatomic distance after many failed placements: 1.6799999999999997
# C: 100 / 100 : Minimum distance = 1.690862
#  Setting new minimum interatomic distance after many failed placements: 1.6699999999999997
# O: 2 / 2 : Minimum distance = 1.673208
#  Setting new minimum interatomic distance after many failed placements: 1.6599999999999997
# H: 2 / 8 : Minimum distance = 1.675866
#  Setting new minimum interatomic distance after many failed placements: 1.6499999999999997
# H: 3 / 8 : Minimum distance = 1.692451
#  Setting new minimum interatomic distance after many failed placements: 1.6399999999999997
# H: 6 / 8 : Minimum distance = 1.702370
#  Setting new minimum interatomic distance after many failed placements: 1.6299999999999997
# H: 8 / 8 : Minimum distance = 1.632090Total Box Mass: 1243.1779999999999 g
# Computed ideal box length for dens 1.500000 is 9.393210 Angstrom
# C: 64 / 100 : Minimum distance = 2.112381
#  Setting new minimum interatomic distance after many failed placements: 1.99
# C: 65 / 100 : Minimum distance = 2.008145
#  Setting new minimum interatomic distance after many failed placements: 1.98
# C: 66 / 100 : Minimum distance = 2.049838
#  Setting new minimum interatomic distance after many failed placements: 1.97
# C: 67 / 100 : Minimum distance = 1.982329
#  Setting new minimum interatomic distance after many failed placements: 1.96
# C: 68 / 100 : Minimum distance = 2.031640
#  Setting new minimum interatomic distance after many failed placements: 1.95
# C: 69 / 100 : Minimum distance = 1.989614
#  Setting new minimum interatomic distance after many failed placements: 1.94
#
#  Setting new minimum interatomic distance after many failed placements: 1.93
# C: 71 / 100 : Minimum distance = 1.946494
#  Setting new minimum interatomic distance after many failed placements: 1.92
# C: 72 / 100 : Minimum distance = 1.987593
#  Setting new minimum interatomic distance after many failed placements: 1.91
# C: 74 / 100 : Minimum distance = 1.931264
#  Setting new minimum interatomic distance after many failed placements: 1.9
#
#  Setting new minimum interatomic distance after many failed placements: 1.89
# C: 76 / 100 : Minimum distance = 1.901875
#  Setting new minimum interatomic distance after many failed placements: 1.88
# C: 77 / 100 : Minimum distance = 1.883164
# ...
#  Setting new minimum interatomic distance after many failed placements: 1.95
#
#  Setting new minimum interatomic distance after many failed placements: 1.94
# C: 69 / 100 : Minimum distance = 1.979547
#  Setting new minimum interatomic distance after many failed placements: 1.93
#
#  Setting new minimum interatomic distance after many failed placements: 1.92
# C: 70 / 100 : Minimum distance = 1.945821
#  Setting new minimum interatomic distance after many failed placements: 1.91
# C: 71 / 100 : Minimum distance = 1.953942
#  Setting new minimum interatomic distance after many failed placements: 1.9
#
#  Setting new minimum interatomic distance after many failed placements: 1.89
#
#  Setting new minimum interatomic distance after many failed placements: 1.88
# C: 72 / 100 : Minimum distance = 1.901115
#  Setting new minimum interatomic distance after many failed placements: 1.8699999999999999
# C: 75 / 100 : Minimum distance = 1.889563
#  Setting new minimum interatomic distance after many failed placements: 1.8599999999999999
# C: 77 / 100 : Minimum distance = 1.903178
#  Setting new minimum interatomic distance after many failed placements: 1.8499999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8399999999999999
# C: 78 / 100 : Minimum distance = 1.851887
#  Setting new minimum interatomic distance after many failed placements: 1.8299999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.8199999999999998
# C: 79 / 100 : Minimum distance = 1.850866
#  Setting new minimum interatomic distance after many failed placements: 1.8099999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7999999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7899999999999998
# C: 82 / 100 : Minimum distance = 1.793557
#  Setting new minimum interatomic distance after many failed placements: 1.7799999999999998
# C: 83 / 100 : Minimum distance = 1.792307
#  Setting new minimum interatomic distance after many failed placements: 1.7699999999999998
# C: 84 / 100 : Minimum distance = 1.826034
#  Setting new minimum interatomic distance after many failed placements: 1.7599999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7499999999999998
# C: 87 / 100 : Minimum distance = 1.789253
#  Setting new minimum interatomic distance after many failed placements: 1.7399999999999998
# C: 89 / 100 : Minimum distance = 1.772844
#  Setting new minimum interatomic distance after many failed placements: 1.7299999999999998
# C: 90 / 100 : Minimum distance = 1.732680
#  Setting new minimum interatomic distance after many failed placements: 1.7199999999999998
# C: 92 / 100 : Minimum distance = 1.808046
#  Setting new minimum interatomic distance after many failed placements: 1.7099999999999997
# C: 93 / 100 : Minimum distance = 1.733434
#  Setting new minimum interatomic distance after many failed placements: 1.6999999999999997
# C: 97 / 100 : Minimum distance = 1.706336
#  Setting new minimum interatomic distance after many failed placements: 1.6899999999999997
# C: 98 / 100 : Minimum distance = 1.835153
#  Setting new minimum interatomic distance after many failed placements: 1.6799999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6699999999999997
# C: 100 / 100 : Minimum distance = 1.736966
#  Setting new minimum interatomic distance after many failed placements: 1.6599999999999997
# O: 4 / 48 : Minimum distance = 1.667957
#  Setting new minimum interatomic distance after many failed placements: 1.6499999999999997
# O: 5 / 48 : Minimum distance = 1.657194
#  Setting new minimum interatomic distance after many failed placements: 1.6399999999999997
# O: 6 / 48 : Minimum distance = 1.668515
#  Setting new minimum interatomic distance after many failed placements: 1.6299999999999997
# O: 8 / 48 : Minimum distance = 1.652449
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999997
# O: 9 / 48 : Minimum distance = 1.610111
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999996
# O: 13 / 48 : Minimum distance = 1.605861
#  Setting new minimum interatomic distance after many failed placements: 1.5899999999999996
# O: 16 / 48 : Minimum distance = 1.653687
#  Setting new minimum interatomic distance after many failed placements: 1.5799999999999996
# O: 18 / 48 : Minimum distance = 1.584394
#  Setting new minimum interatomic distance after many failed placements: 1.5699999999999996
# O: 21 / 48 : Minimum distance = 1.599215
#  Setting new minimum interatomic distance after many failed placements: 1.5599999999999996
# O: 23 / 48 : Minimum distance = 1.584879
#  Setting new minimum interatomic distance after many failed placements: 1.5499999999999996
# O: 27 / 48 : Minimum distance = 1.639350
#  Setting new minimum interatomic distance after many failed placements: 1.5399999999999996
# O: 29 / 48 : Minimum distance = 1.611732
#  Setting new minimum interatomic distance after many failed placements: 1.5299999999999996
# O: 32 / 48 : Minimum distance = 1.589944
#  Setting new minimum interatomic distance after many failed placements: 1.5199999999999996
#
#  Setting new minimum interatomic distance after many failed placements: 1.5099999999999996
# O: 40 / 48 : Minimum distance = 1.527338
#  Setting new minimum interatomic distance after many failed placements: 1.4999999999999996
# O: 42 / 48 : Minimum distance = 1.520125
#  Setting new minimum interatomic distance after many failed placements: 1.4899999999999995
#
#  Setting new minimum interatomic distance after many failed placements: 1.4799999999999995
# O: 44 / 48 : Minimum distance = 1.551928
#  Setting new minimum interatomic distance after many failed placements: 1.4699999999999995
# O: 45 / 48 : Minimum distance = 1.475023
#  Setting new minimum interatomic distance after many failed placements: 1.4599999999999995
# H: 1 / 40 : Minimum distance = 1.4666666
#  Setting new minimum interatomic distance after many failed placements: 1.4499999999999995
# H: 5 / 40 : Minimum distance = 1.453850
#  Setting new minimum interatomic distance after many failed placements: 1.4399999999999995
# H: 7 / 40 : Minimum distance = 1.447074
#  Setting new minimum interatomic distance after many failed placements: 1.4299999999999995
# H: 10 / 40 : Minimum distance = 1.448379
#  Setting new minimum interatomic distance after many failed placements: 1.4199999999999995
# H: 15 / 40 : Minimum distance = 1.472087
#  Setting new minimum interatomic distance after many failed placements: 1.4099999999999995
# H: 18 / 40 : Minimum distance = 1.420128
#  Setting new minimum interatomic distance after many failed placements: 1.3999999999999995
# H: 20 / 40 : Minimum distance = 1.414600
#  Setting new minimum interatomic distance after many failed placements: 1.3899999999999995
# H: 23 / 40 : Minimum distance = 1.415183
#  Setting new minimum interatomic distance after many failed placements: 1.3799999999999994
# H: 24 / 40 : Minimum distance = 1.385632
#  Setting new minimum interatomic distance after many failed placements: 1.3699999999999994
# H: 27 / 40 : Minimum distance = 1.438313
#  Setting new minimum interatomic distance after many failed placements: 1.3599999999999994
# H: 31 / 40 : Minimum distance = 1.391751
#  Setting new minimum interatomic distance after many failed placements: 1.3499999999999994
# H: 36 / 40 : Minimum distance = 1.382125
#  Setting new minimum interatomic distance after many failed placements: 1.3399999999999994
# H: 39 / 40 : Minimum distance = 1.374107
#  Setting new minimum interatomic distance after many failed placements: 1.3299999999999994
# H: 40 / 40 : Minimum distance = 1.361856Total Box Mass: 2017.436 g
# Computed ideal box length for dens 2.500000 is 9.310077 Angstrom
# C: 60 / 100 : Minimum distance = 2.017439
#  Setting new minimum interatomic distance after many failed placements: 1.99
# C: 64 / 100 : Minimum distance = 2.056343
#  Setting new minimum interatomic distance after many failed placements: 1.98
#
#  Setting new minimum interatomic distance after many failed placements: 1.97
# C: 68 / 100 : Minimum distance = 1.970852
#  Setting new minimum interatomic distance after many failed placements: 1.96
#
#  Setting new minimum interatomic distance after many failed placements: 1.95
#
#  Setting new minimum interatomic distance after many failed placements: 1.94
# C: 70 / 100 : Minimum distance = 1.943082
#  Setting new minimum interatomic distance after many failed placements: 1.93
# C: 72 / 100 : Minimum distance = 1.935567
#  Setting new minimum interatomic distance after many failed placements: 1.92
#
#  Setting new minimum interatomic distance after many failed placements: 1.91
#
#  Setting new minimum interatomic distance after many failed placements: 1.9
#
#  Setting new minimum interatomic distance after many failed placements: 1.89
# C: 74 / 100 : Minimum distance = 1.904022
#  Setting new minimum interatomic distance after many failed placements: 1.88
# C: 76 / 100 : Minimum distance = 1.889339
#  Setting new minimum interatomic distance after many failed placements: 1.8699999999999999
# C: 77 / 100 : Minimum distance = 1.884698
#  Setting new minimum interatomic distance after many failed placements: 1.8599999999999999
# C: 79 / 100 : Minimum distance = 1.912621
#  Setting new minimum interatomic distance after many failed placements: 1.8499999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.8399999999999999
# C: 81 / 100 : Minimum distance = 1.863633
#  Setting new minimum interatomic distance after many failed placements: 1.8299999999999998
# C: 84 / 100 : Minimum distance = 1.844258
#  Setting new minimum interatomic distance after many failed placements: 1.8199999999999998
# C: 85 / 100 : Minimum distance = 1.826205
#  Setting new minimum interatomic distance after many failed placements: 1.8099999999999998
# C: 86 / 100 : Minimum distance = 1.849065
#  Setting new minimum interatomic distance after many failed placements: 1.7999999999999998
# C: 87 / 100 : Minimum distance = 1.813879
#  Setting new minimum interatomic distance after many failed placements: 1.7899999999999998
# C: 88 / 100 : Minimum distance = 1.794094
#  Setting new minimum interatomic distance after many failed placements: 1.7799999999999998
# C: 89 / 100 : Minimum distance = 1.789746
#  Setting new minimum interatomic distance after many failed placements: 1.7699999999999998
# C: 91 / 100 : Minimum distance = 1.798684
#  Setting new minimum interatomic distance after many failed placements: 1.7599999999999998
# C: 93 / 100 : Minimum distance = 1.818857
#  Setting new minimum interatomic distance after many failed placements: 1.7499999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7399999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.7299999999999998
# C: 94 / 100 : Minimum distance = 1.733008
#  Setting new minimum interatomic distance after many failed placements: 1.7199999999999998
# C: 95 / 100 : Minimum distance = 1.745925
#  Setting new minimum interatomic distance after many failed placements: 1.7099999999999997
# C: 97 / 100 : Minimum distance = 1.797309
#  Setting new minimum interatomic distance after many failed placements: 1.6999999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6899999999999997
# C: 100 / 100 : Minimum distance = 1.691514
#  Setting new minimum interatomic distance after many failed placements: 1.6799999999999997
# O: 1 / 48 : Minimum distance = 1.751555
#  Setting new minimum interatomic distance after many failed placements: 1.6699999999999997
# O: 5 / 48 : Minimum distance = 1.718609
#  Setting new minimum interatomic distance after many failed placements: 1.6599999999999997
# O: 8 / 48 : Minimum distance = 1.673121
#  Setting new minimum interatomic distance after many failed placements: 1.6499999999999997
# O: 9 / 48 : Minimum distance = 1.652343
#  Setting new minimum interatomic distance after many failed placements: 1.6399999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.6299999999999997
# O: 10 / 48 : Minimum distance = 1.642638
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999997
# O: 12 / 48 : Minimum distance = 1.624688
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999996
# O: 14 / 48 : Minimum distance = 1.610915
#  Setting new minimum interatomic distance after many failed placements: 1.5899999999999996
# O: 18 / 48 : Minimum distance = 1.595134
#  Setting new minimum interatomic distance after many failed placements: 1.5799999999999996
# O: 19 / 48 : Minimum distance = 1.580768
#  Setting new minimum interatomic distance after many failed placements: 1.5699999999999996
# O: 20 / 48 : Minimum distance = 1.577844
#  Setting new minimum interatomic distance after many failed placements: 1.5599999999999996
#
#  Setting new minimum interatomic distance after many failed placements: 1.5499999999999996
# O: 21 / 48 : Minimum distance = 1.590309
#  Setting new minimum interatomic distance after many failed placements: 1.5399999999999996
# O: 22 / 48 : Minimum distance = 1.547342
#  Setting new minimum interatomic distance after many failed placements: 1.5299999999999996
# O: 24 / 48 : Minimum distance = 1.530612
#  Setting new minimum interatomic distance after many failed placements: 1.5199999999999996
# O: 27 / 48 : Minimum distance = 1.522817
#  Setting new minimum interatomic distance after many failed placements: 1.5099999999999996
# O: 28 / 48 : Minimum distance = 1.551428
#  Setting new minimum interatomic distance after many failed placements: 1.4999999999999996
# O: 33 / 48 : Minimum distance = 1.528709
#  Setting new minimum interatomic distance after many failed placements: 1.4899999999999995
# O: 36 / 48 : Minimum distance = 1.519594
#  Setting new minimum interatomic distance after many failed placements: 1.4799999999999995
# O: 42 / 48 : Minimum distance = 1.500230
#  Setting new minimum interatomic distance after many failed placements: 1.4699999999999995
# O: 44 / 48 : Minimum distance = 1.525792
#  Setting new minimum interatomic distance after many failed placements: 1.4599999999999995
# O: 46 / 48 : Minimum distance = 1.460517
#  Setting new minimum interatomic distance after many failed placements: 1.4499999999999995
# H: 3 / 48 : Minimum distance = 1.4719040
#  Setting new minimum interatomic distance after many failed placements: 1.4399999999999995
# H: 4 / 48 : Minimum distance = 1.446706
#  Setting new minimum interatomic distance after many failed placements: 1.4299999999999995
# H: 5 / 48 : Minimum distance = 1.436266
#  Setting new minimum interatomic distance after many failed placements: 1.4199999999999995
# H: 10 / 48 : Minimum distance = 1.428002
#  Setting new minimum interatomic distance after many failed placements: 1.4099999999999995
# H: 16 / 48 : Minimum distance = 1.411709
#  Setting new minimum interatomic distance after many failed placements: 1.3999999999999995
# H: 20 / 48 : Minimum distance = 1.485535
#  Setting new minimum interatomic distance after many failed placements: 1.3899999999999995
# H: 29 / 48 : Minimum distance = 1.406677
#  Setting new minimum interatomic distance after many failed placements: 1.3799999999999994
# H: 30 / 48 : Minimum distance = 1.414812
#  Setting new minimum interatomic distance after many failed placements: 1.3699999999999994
# H: 33 / 48 : Minimum distance = 1.370952
#  Setting new minimum interatomic distance after many failed placements: 1.3599999999999994
# H: 35 / 48 : Minimum distance = 1.381772
#  Setting new minimum interatomic distance after many failed placements: 1.3499999999999994
# H: 38 / 48 : Minimum distance = 1.378843
#  Setting new minimum interatomic distance after many failed placements: 1.3399999999999994
# H: 41 / 48 : Minimum distance = 1.370403
#  Setting new minimum interatomic distance after many failed placements: 1.3299999999999994
# H: 48 / 48 : Minimum distance = 1.389346

# %%
if not os.path.exists('./st_h2_o1'):
    os.mkdir('./st_h2_o1')

for dens in densities:
    if not os.path.exists(os.path.join('./st_h2_o1', str(dens))):
        os.mkdir(os.path.join('./st_h2_o1', str(dens)))
    for stoi in stoichiometries_h2o:
        if not os.path.exists(os.path.join('./st_h2_o1', str(dens), stoi)):
            os.mkdir(os.path.join('./st_h2_o1', str(dens), stoi))
        builder = boxbuilder(dens, stoi, rmin=1.8)
        builder.save_struct(save_path=os.path.join('./st_h2_o1', str(dens), stoi))
# Out:
# Total Box Mass: 1219.115 g
# Computed ideal box length for dens 1.500000 is 9.332209 Angstrom
# C: 84 / 100 : Minimum distance = 1.831248
#  Setting new minimum interatomic distance after many failed placements: 1.79
# C: 90 / 100 : Minimum distance = 1.814115
#  Setting new minimum interatomic distance after many failed placements: 1.78
# C: 94 / 100 : Minimum distance = 1.793107
#  Setting new minimum interatomic distance after many failed placements: 1.77
# C: 95 / 100 : Minimum distance = 1.791786
#  Setting new minimum interatomic distance after many failed placements: 1.76
# C: 96 / 100 : Minimum distance = 1.781820
#  Setting new minimum interatomic distance after many failed placements: 1.75
# C: 99 / 100 : Minimum distance = 1.798360
#  Setting new minimum interatomic distance after many failed placements: 1.74
# O: 1 / 1 : Minimum distance = 1.7830154741
#  Setting new minimum interatomic distance after many failed placements: 1.73
#
#  Setting new minimum interatomic distance after many failed placements: 1.72
#
#  Setting new minimum interatomic distance after many failed placements: 1.71
# H: 1 / 2 : Minimum distance = 1.720790
#  Setting new minimum interatomic distance after many failed placements: 1.7
#
#  Setting new minimum interatomic distance after many failed placements: 1.69
# H: 2 / 2 : Minimum distance = 1.759963Total Box Mass: 1237.1299999999999 g
# Computed ideal box length for dens 1.500000 is 9.377952 Angstrom
# C: 86 / 100 : Minimum distance = 1.901290
#  Setting new minimum interatomic distance after many failed placements: 1.79
# C: 88 / 100 : Minimum distance = 1.835362
#  Setting new minimum interatomic distance after many failed placements: 1.78
# C: 89 / 100 : Minimum distance = 1.829094
#  Setting new minimum interatomic distance after many failed placements: 1.77
# C: 91 / 100 : Minimum distance = 1.776084
#  Setting new minimum interatomic distance after many failed placements: 1.76
# C: 92 / 100 : Minimum distance = 1.830427
#  Setting new minimum interatomic distance after many failed placements: 1.75
# C: 93 / 100 : Minimum distance = 1.755693
#  Setting new minimum interatomic distance after many failed placements: 1.74
# C: 95 / 100 : Minimum distance = 1.752040
#  Setting new minimum interatomic distance after many failed placements: 1.73
# C: 97 / 100 : Minimum distance = 1.742945
#  Setting new minimum interatomic distance after many failed placements: 1.72
# C: 100 / 100 : Minimum distance = 1.779243
#  Setting new minimum interatomic distance after many failed placements: 1.71
# O: 2 / 2 : Minimum distance = 1.845734
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 1 / 4 : Minimum distance = 1.789100
#  Setting new minimum interatomic distance after many failed placements: 1.69
# H: 4 / 4 : Minimum distance = 1.699172Total Box Mass: 1255.145 g
# Computed ideal box length for dens 1.500000 is 9.423254 Angstrom
# C: 87 / 100 : Minimum distance = 1.830146
#  Setting new minimum interatomic distance after many failed placements: 1.79
# C: 93 / 100 : Minimum distance = 1.790681
#  Setting new minimum interatomic distance after many failed placements: 1.78
# C: 94 / 100 : Minimum distance = 1.791272
#  Setting new minimum interatomic distance after many failed placements: 1.77
# C: 97 / 100 : Minimum distance = 1.780179
#  Setting new minimum interatomic distance after many failed placements: 1.76
# C: 98 / 100 : Minimum distance = 1.800313
#  Setting new minimum interatomic distance after many failed placements: 1.75
#
#  Setting new minimum interatomic distance after many failed placements: 1.74
# C: 99 / 100 : Minimum distance = 1.797940
#  Setting new minimum interatomic distance after many failed placements: 1.73
#
#  Setting new minimum interatomic distance after many failed placements: 1.72
# C: 100 / 100 : Minimum distance = 1.765960
#  Setting new minimum interatomic distance after many failed placements: 1.71
# O: 1 / 3 : Minimum distance = 1.724446
#  Setting new minimum interatomic distance after many failed placements: 1.7
#
#  Setting new minimum interatomic distance after many failed placements: 1.69
# O: 3 / 3 : Minimum distance = 1.716195
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 2 / 6 : Minimum distance = 1.715741
#  Setting new minimum interatomic distance after many failed placements: 1.67
#
#  Setting new minimum interatomic distance after many failed placements: 1.66
# H: 4 / 6 : Minimum distance = 1.660987
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 6 / 6 : Minimum distance = 1.726270Total Box Mass: 1273.16 g
# Computed ideal box length for dens 1.500000 is 9.468123 Angstrom
# C: 85 / 100 : Minimum distance = 1.861315
#  Setting new minimum interatomic distance after many failed placements: 1.79
# C: 92 / 100 : Minimum distance = 1.799793
#  Setting new minimum interatomic distance after many failed placements: 1.78
# C: 95 / 100 : Minimum distance = 1.803646
#  Setting new minimum interatomic distance after many failed placements: 1.77
# C: 98 / 100 : Minimum distance = 1.833416
#  Setting new minimum interatomic distance after many failed placements: 1.76
# C: 100 / 100 : Minimum distance = 1.766727
#  Setting new minimum interatomic distance after many failed placements: 1.75
#
#  Setting new minimum interatomic distance after many failed placements: 1.74
#
#  Setting new minimum interatomic distance after many failed placements: 1.73
# O: 2 / 4 : Minimum distance = 1.747109
#  Setting new minimum interatomic distance after many failed placements: 1.72
#
#  Setting new minimum interatomic distance after many failed placements: 1.71
# O: 4 / 4 : Minimum distance = 1.726473
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 1 / 8 : Minimum distance = 1.731699
#  Setting new minimum interatomic distance after many failed placements: 1.69
#
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 3 / 8 : Minimum distance = 1.721139
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 5 / 8 : Minimum distance = 1.714035
#  Setting new minimum interatomic distance after many failed placements: 1.66
# H: 6 / 8 : Minimum distance = 1.670154
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 8 / 8 : Minimum distance = 1.664716Total Box Mass: 1291.1749999999997 g
# Computed ideal box length for dens 1.500000 is 9.512572 Angstrom
# C: 89 / 100 : Minimum distance = 1.838383
#  Setting new minimum interatomic distance after many failed placements: 1.79
# C: 94 / 100 : Minimum distance = 1.816221
#  Setting new minimum interatomic distance after many failed placements: 1.78
# C: 95 / 100 : Minimum distance = 1.783878
#  Setting new minimum interatomic distance after many failed placements: 1.77
#
#  Setting new minimum interatomic distance after many failed placements: 1.76
# C: 96 / 100 : Minimum distance = 1.810313
#  Setting new minimum interatomic distance after many failed placements: 1.75
#
#  Setting new minimum interatomic distance after many failed placements: 1.74
# C: 99 / 100 : Minimum distance = 1.745449
#  Setting new minimum interatomic distance after many failed placements: 1.73
#
#  Setting new minimum interatomic distance after many failed placements: 1.72
# C: 100 / 100 : Minimum distance = 1.735574
#  Setting new minimum interatomic distance after many failed placements: 1.71
# O: 1 / 5 : Minimum distance = 1.769943
#  Setting new minimum interatomic distance after many failed placements: 1.7
# O: 3 / 5 : Minimum distance = 1.705346
#  Setting new minimum interatomic distance after many failed placements: 1.69
# O: 4 / 5 : Minimum distance = 1.709180
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 2 / 10 : Minimum distance = 1.685855
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 3 / 10 : Minimum distance = 1.717210
#  Setting new minimum interatomic distance after many failed placements: 1.66
#
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 6 / 10 : Minimum distance = 1.686310
#  Setting new minimum interatomic distance after many failed placements: 1.64
# H: 8 / 10 : Minimum distance = 1.670554
#  Setting new minimum interatomic distance after many failed placements: 1.63
# H: 10 / 10 : Minimum distance = 1.654714Total Box Mass: 1309.1899999999998 g
# Computed ideal box length for dens 1.500000 is 9.556609 Angstrom
# C: 92 / 100 : Minimum distance = 1.820167
#  Setting new minimum interatomic distance after many failed placements: 1.79
# C: 96 / 100 : Minimum distance = 1.800215
#  Setting new minimum interatomic distance after many failed placements: 1.78
# C: 100 / 100 : Minimum distance = 1.820785
#  Setting new minimum interatomic distance after many failed placements: 1.77
# O: 2 / 6 : Minimum distance = 1.855277
#  Setting new minimum interatomic distance after many failed placements: 1.76
#
#  Setting new minimum interatomic distance after many failed placements: 1.75
#
#  Setting new minimum interatomic distance after many failed placements: 1.74
# O: 3 / 6 : Minimum distance = 1.744079
#  Setting new minimum interatomic distance after many failed placements: 1.73
# O: 4 / 6 : Minimum distance = 1.749427
#  Setting new minimum interatomic distance after many failed placements: 1.72
# O: 5 / 6 : Minimum distance = 1.746516
#  Setting new minimum interatomic distance after many failed placements: 1.71
# H: 3 / 12 : Minimum distance = 1.726191
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 6 / 12 : Minimum distance = 1.736517
#  Setting new minimum interatomic distance after many failed placements: 1.69
#
#  Setting new minimum interatomic distance after many failed placements: 1.68
#
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 7 / 12 : Minimum distance = 1.709471
#  Setting new minimum interatomic distance after many failed placements: 1.66
# H: 11 / 12 : Minimum distance = 1.673704
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 12 / 12 : Minimum distance = 1.664579Total Box Mass: 1327.205 g
# Computed ideal box length for dens 1.500000 is 9.600244 Angstrom
# C: 85 / 100 : Minimum distance = 1.804387
#  Setting new minimum interatomic distance after many failed placements: 1.79
# C: 91 / 100 : Minimum distance = 1.880742
#  Setting new minimum interatomic distance after many failed placements: 1.78
# C: 94 / 100 : Minimum distance = 1.792697
#  Setting new minimum interatomic distance after many failed placements: 1.77
# C: 98 / 100 : Minimum distance = 1.783479
#  Setting new minimum interatomic distance after many failed placements: 1.76
# C: 99 / 100 : Minimum distance = 1.804304
#  Setting new minimum interatomic distance after many failed placements: 1.75
# O: 1 / 7 : Minimum distance = 1.7531092272
#  Setting new minimum interatomic distance after many failed placements: 1.74
# O: 4 / 7 : Minimum distance = 1.791621
#  Setting new minimum interatomic distance after many failed placements: 1.73
#
#  Setting new minimum interatomic distance after many failed placements: 1.72
# O: 6 / 7 : Minimum distance = 1.732328
#  Setting new minimum interatomic distance after many failed placements: 1.71
# H: 1 / 14 : Minimum distance = 1.754781
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 3 / 14 : Minimum distance = 1.724410
#  Setting new minimum interatomic distance after many failed placements: 1.69
# H: 6 / 14 : Minimum distance = 1.772773
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 11 / 14 : Minimum distance = 1.719858
#  Setting new minimum interatomic distance after many failed placements: 1.67
#
#  Setting new minimum interatomic distance after many failed placements: 1.66
# H: 13 / 14 : Minimum distance = 1.690771
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 14 / 14 : Minimum distance = 1.702700Total Box Mass: 1345.2199999999998 g
# Computed ideal box length for dens 1.500000 is 9.643485 Angstrom
# C: 93 / 100 : Minimum distance = 1.897666
#  Setting new minimum interatomic distance after many failed placements: 1.79
# C: 96 / 100 : Minimum distance = 1.852264
#  Setting new minimum interatomic distance after many failed placements: 1.78
# C: 98 / 100 : Minimum distance = 1.794750
#  Setting new minimum interatomic distance after many failed placements: 1.77
# C: 99 / 100 : Minimum distance = 1.819699
#  Setting new minimum interatomic distance after many failed placements: 1.76
# O: 1 / 8 : Minimum distance = 1.7663863800
#  Setting new minimum interatomic distance after many failed placements: 1.75
# O: 4 / 8 : Minimum distance = 1.830965
#  Setting new minimum interatomic distance after many failed placements: 1.74
#
#  Setting new minimum interatomic distance after many failed placements: 1.73
#
#  Setting new minimum interatomic distance after many failed placements: 1.72
# O: 6 / 8 : Minimum distance = 1.783493
#  Setting new minimum interatomic distance after many failed placements: 1.71
# O: 7 / 8 : Minimum distance = 1.722669
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 1 / 16 : Minimum distance = 1.707825
#  Setting new minimum interatomic distance after many failed placements: 1.69
# H: 3 / 16 : Minimum distance = 1.735099
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 7 / 16 : Minimum distance = 1.714849
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 9 / 16 : Minimum distance = 1.709061
#  Setting new minimum interatomic distance after many failed placements: 1.66
#
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 10 / 16 : Minimum distance = 1.665161
#  Setting new minimum interatomic distance after many failed placements: 1.64
# H: 12 / 16 : Minimum distance = 1.698292
#  Setting new minimum interatomic distance after many failed placements: 1.63
# H: 13 / 16 : Minimum distance = 1.650878
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
# H: 16 / 16 : Minimum distance = 1.654268Total Box Mass: 1363.235 g
# Computed ideal box length for dens 1.500000 is 9.686343 Angstrom
# C: 92 / 100 : Minimum distance = 1.800876
#  Setting new minimum interatomic distance after many failed placements: 1.79
# C: 94 / 100 : Minimum distance = 1.799723
#  Setting new minimum interatomic distance after many failed placements: 1.78
# C: 99 / 100 : Minimum distance = 1.796372
#  Setting new minimum interatomic distance after many failed placements: 1.77
# O: 4 / 9 : Minimum distance = 1.7769618570
#  Setting new minimum interatomic distance after many failed placements: 1.76
# O: 5 / 9 : Minimum distance = 1.772027
#  Setting new minimum interatomic distance after many failed placements: 1.75
# O: 6 / 9 : Minimum distance = 1.782741
#  Setting new minimum interatomic distance after many failed placements: 1.74
# O: 7 / 9 : Minimum distance = 1.761069
#  Setting new minimum interatomic distance after many failed placements: 1.73
# O: 8 / 9 : Minimum distance = 1.766958
#  Setting new minimum interatomic distance after many failed placements: 1.72
# O: 9 / 9 : Minimum distance = 1.747105
#  Setting new minimum interatomic distance after many failed placements: 1.71
# H: 1 / 18 : Minimum distance = 1.714140
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 2 / 18 : Minimum distance = 1.749667
#  Setting new minimum interatomic distance after many failed placements: 1.69
#
#  Setting new minimum interatomic distance after many failed placements: 1.68
#
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 4 / 18 : Minimum distance = 1.680676
#  Setting new minimum interatomic distance after many failed placements: 1.66
# H: 7 / 18 : Minimum distance = 1.745878
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 9 / 18 : Minimum distance = 1.676897
#  Setting new minimum interatomic distance after many failed placements: 1.64
# H: 10 / 18 : Minimum distance = 1.691026
#  Setting new minimum interatomic distance after many failed placements: 1.63
# H: 12 / 18 : Minimum distance = 1.691036
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
# H: 14 / 18 : Minimum distance = 1.641392
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
# H: 17 / 18 : Minimum distance = 1.651181
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999999
# H: 18 / 18 : Minimum distance = 1.610806Total Box Mass: 1381.25 g
# Computed ideal box length for dens 1.500000 is 9.728824 Angstrom
# C: 94 / 100 : Minimum distance = 1.867580
#  Setting new minimum interatomic distance after many failed placements: 1.79
# O: 3 / 10 : Minimum distance = 1.801205190
#  Setting new minimum interatomic distance after many failed placements: 1.78
#
#  Setting new minimum interatomic distance after many failed placements: 1.77
#
#  Setting new minimum interatomic distance after many failed placements: 1.76
# O: 6 / 10 : Minimum distance = 1.816069
#  Setting new minimum interatomic distance after many failed placements: 1.75
#
#  Setting new minimum interatomic distance after many failed placements: 1.74
# O: 8 / 10 : Minimum distance = 1.834910
#  Setting new minimum interatomic distance after many failed placements: 1.73
#
#  Setting new minimum interatomic distance after many failed placements: 1.72
# O: 10 / 10 : Minimum distance = 1.733742
#  Setting new minimum interatomic distance after many failed placements: 1.71
# H: 5 / 20 : Minimum distance = 1.712917
#  Setting new minimum interatomic distance after many failed placements: 1.7
#
#  Setting new minimum interatomic distance after many failed placements: 1.69
# H: 6 / 20 : Minimum distance = 1.712060
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 9 / 20 : Minimum distance = 1.706193
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 12 / 20 : Minimum distance = 1.694220
#  Setting new minimum interatomic distance after many failed placements: 1.66
# H: 13 / 20 : Minimum distance = 1.686008
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 16 / 20 : Minimum distance = 1.669231
#  Setting new minimum interatomic distance after many failed placements: 1.64
# H: 18 / 20 : Minimum distance = 1.694729
#  Setting new minimum interatomic distance after many failed placements: 1.63
# H: 20 / 20 : Minimum distance = 1.649183Total Box Mass: 1399.2649999999999 g
# Computed ideal box length for dens 1.500000 is 9.770938 Angstrom
# C: 92 / 100 : Minimum distance = 1.813965
#  Setting new minimum interatomic distance after many failed placements: 1.79
# C: 97 / 100 : Minimum distance = 1.845505
#  Setting new minimum interatomic distance after many failed placements: 1.78
# C: 100 / 100 : Minimum distance = 1.847766
#  Setting new minimum interatomic distance after many failed placements: 1.77
# O: 3 / 11 : Minimum distance = 1.811695
#  Setting new minimum interatomic distance after many failed placements: 1.76
# O: 7 / 11 : Minimum distance = 1.801188
#  Setting new minimum interatomic distance after many failed placements: 1.75
# O: 9 / 11 : Minimum distance = 1.782151
#  Setting new minimum interatomic distance after many failed placements: 1.74
#
#  Setting new minimum interatomic distance after many failed placements: 1.73
# O: 10 / 11 : Minimum distance = 1.737746
#  Setting new minimum interatomic distance after many failed placements: 1.72
# H: 1 / 22 : Minimum distance = 1.7271480
#  Setting new minimum interatomic distance after many failed placements: 1.71
# H: 2 / 22 : Minimum distance = 1.735409
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 5 / 22 : Minimum distance = 1.775109
#  Setting new minimum interatomic distance after many failed placements: 1.69
# H: 6 / 22 : Minimum distance = 1.735239
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 8 / 22 : Minimum distance = 1.705291
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 10 / 22 : Minimum distance = 1.731080
#  Setting new minimum interatomic distance after many failed placements: 1.66
# H: 13 / 22 : Minimum distance = 1.699537
#  Setting new minimum interatomic distance after many failed placements: 1.65
#
#  Setting new minimum interatomic distance after many failed placements: 1.64
# H: 16 / 22 : Minimum distance = 1.677974
#  Setting new minimum interatomic distance after many failed placements: 1.63
# H: 17 / 22 : Minimum distance = 1.648489
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
# H: 20 / 22 : Minimum distance = 1.623875
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
# H: 22 / 22 : Minimum distance = 1.624445Total Box Mass: 1417.28 g
# Computed ideal box length for dens 1.500000 is 9.812691 Angstrom
# C: 98 / 100 : Minimum distance = 1.816454
#  Setting new minimum interatomic distance after many failed placements: 1.79
# O: 3 / 12 : Minimum distance = 1.800933092
#  Setting new minimum interatomic distance after many failed placements: 1.78
# O: 8 / 12 : Minimum distance = 1.788679
#  Setting new minimum interatomic distance after many failed placements: 1.77
#
#  Setting new minimum interatomic distance after many failed placements: 1.76
# O: 9 / 12 : Minimum distance = 1.760673
#  Setting new minimum interatomic distance after many failed placements: 1.75
# H: 2 / 24 : Minimum distance = 1.7542727
#  Setting new minimum interatomic distance after many failed placements: 1.74
#
#  Setting new minimum interatomic distance after many failed placements: 1.73
# H: 3 / 24 : Minimum distance = 1.732924
#  Setting new minimum interatomic distance after many failed placements: 1.72
#
#  Setting new minimum interatomic distance after many failed placements: 1.71
# H: 5 / 24 : Minimum distance = 1.718962
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 6 / 24 : Minimum distance = 1.716337
#  Setting new minimum interatomic distance after many failed placements: 1.69
#
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 11 / 24 : Minimum distance = 1.680732
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 13 / 24 : Minimum distance = 1.692329
#  Setting new minimum interatomic distance after many failed placements: 1.66
#
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 15 / 24 : Minimum distance = 1.735654
#  Setting new minimum interatomic distance after many failed placements: 1.64
# H: 18 / 24 : Minimum distance = 1.701295
#  Setting new minimum interatomic distance after many failed placements: 1.63
# H: 21 / 24 : Minimum distance = 1.667203
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
# H: 24 / 24 : Minimum distance = 1.629338Total Box Mass: 1435.295 g
# Computed ideal box length for dens 1.500000 is 9.854093 Angstrom
# C: 95 / 100 : Minimum distance = 1.805134
#  Setting new minimum interatomic distance after many failed placements: 1.79
# C: 99 / 100 : Minimum distance = 1.814955
#  Setting new minimum interatomic distance after many failed placements: 1.78
# O: 5 / 13 : Minimum distance = 1.875257751
#  Setting new minimum interatomic distance after many failed placements: 1.77
#
#  Setting new minimum interatomic distance after many failed placements: 1.76
# O: 8 / 13 : Minimum distance = 1.762915
#  Setting new minimum interatomic distance after many failed placements: 1.75
# O: 10 / 13 : Minimum distance = 1.753717
#  Setting new minimum interatomic distance after many failed placements: 1.74
# O: 13 / 13 : Minimum distance = 1.758050
#  Setting new minimum interatomic distance after many failed placements: 1.73
# H: 2 / 26 : Minimum distance = 1.769174
#  Setting new minimum interatomic distance after many failed placements: 1.72
# H: 3 / 26 : Minimum distance = 1.721622
#  Setting new minimum interatomic distance after many failed placements: 1.71
# H: 6 / 26 : Minimum distance = 1.786890
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 10 / 26 : Minimum distance = 1.709892
#  Setting new minimum interatomic distance after many failed placements: 1.69
#
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 13 / 26 : Minimum distance = 1.688646
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 17 / 26 : Minimum distance = 1.698281
#  Setting new minimum interatomic distance after many failed placements: 1.66
#
#  Setting new minimum interatomic distance after many failed placements: 1.65
#  Setting new minimum interatomic distance after many failed placements: 1.64
# H: 19 / 26 : Minimum distance = 1.640524
#  Setting new minimum interatomic distance after many failed placements: 1.63
# H: 21 / 26 : Minimum distance = 1.661430
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
# H: 22 / 26 : Minimum distance = 1.638288
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
# H: 25 / 26 : Minimum distance = 1.662190
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999999
# H: 26 / 26 : Minimum distance = 1.664141Total Box Mass: 1453.31 g
# Computed ideal box length for dens 1.500000 is 9.895149 Angstrom
# C: 93 / 100 : Minimum distance = 1.839694
#  Setting new minimum interatomic distance after many failed placements: 1.79
# O: 2 / 14 : Minimum distance = 1.875272923
#  Setting new minimum interatomic distance after many failed placements: 1.78
# O: 7 / 14 : Minimum distance = 1.825253
#  Setting new minimum interatomic distance after many failed placements: 1.77
# O: 8 / 14 : Minimum distance = 1.788056
#  Setting new minimum interatomic distance after many failed placements: 1.76
# O: 10 / 14 : Minimum distance = 1.803679
#  Setting new minimum interatomic distance after many failed placements: 1.75
#
#  Setting new minimum interatomic distance after many failed placements: 1.74
#
#  Setting new minimum interatomic distance after many failed placements: 1.73
#
#  Setting new minimum interatomic distance after many failed placements: 1.72
# O: 12 / 14 : Minimum distance = 1.721765
#  Setting new minimum interatomic distance after many failed placements: 1.71
# O: 14 / 14 : Minimum distance = 1.721386
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 1 / 28 : Minimum distance = 1.780355
#  Setting new minimum interatomic distance after many failed placements: 1.69
# H: 5 / 28 : Minimum distance = 1.701613
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 9 / 28 : Minimum distance = 1.718274
#  Setting new minimum interatomic distance after many failed placements: 1.67
#
#  Setting new minimum interatomic distance after many failed placements: 1.66
# H: 10 / 28 : Minimum distance = 1.727119
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 16 / 28 : Minimum distance = 1.657841
#  Setting new minimum interatomic distance after many failed placements: 1.64
#
#  Setting new minimum interatomic distance after many failed placements: 1.63
# H: 19 / 28 : Minimum distance = 1.644580
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
# H: 21 / 28 : Minimum distance = 1.622964
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
# H: 23 / 28 : Minimum distance = 1.635007
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999999
# H: 24 / 28 : Minimum distance = 1.608538
#  Setting new minimum interatomic distance after many failed placements: 1.5899999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.5799999999999998
# H: 28 / 28 : Minimum distance = 1.657467Total Box Mass: 1471.325 g
# Computed ideal box length for dens 1.500000 is 9.935867 Angstrom
# C: 96 / 100 : Minimum distance = 1.873919
#  Setting new minimum interatomic distance after many failed placements: 1.79
# C: 100 / 100 : Minimum distance = 1.793462
#  Setting new minimum interatomic distance after many failed placements: 1.78
# O: 4 / 15 : Minimum distance = 1.782597
#  Setting new minimum interatomic distance after many failed placements: 1.77
# O: 10 / 15 : Minimum distance = 1.775842
#  Setting new minimum interatomic distance after many failed placements: 1.76
# O: 13 / 15 : Minimum distance = 1.765535
#  Setting new minimum interatomic distance after many failed placements: 1.75
# H: 2 / 30 : Minimum distance = 1.7941510
#  Setting new minimum interatomic distance after many failed placements: 1.74
# H: 3 / 30 : Minimum distance = 1.765759
#  Setting new minimum interatomic distance after many failed placements: 1.73
#
#  Setting new minimum interatomic distance after many failed placements: 1.72
# H: 4 / 30 : Minimum distance = 1.747869
#  Setting new minimum interatomic distance after many failed placements: 1.71
# H: 5 / 30 : Minimum distance = 1.765636
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 10 / 30 : Minimum distance = 1.734296
#  Setting new minimum interatomic distance after many failed placements: 1.69
#
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 12 / 30 : Minimum distance = 1.711475
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 13 / 30 : Minimum distance = 1.724301
#  Setting new minimum interatomic distance after many failed placements: 1.66
#
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 14 / 30 : Minimum distance = 1.650454
#  Setting new minimum interatomic distance after many failed placements: 1.64
#
#  Setting new minimum interatomic distance after many failed placements: 1.63
# H: 18 / 30 : Minimum distance = 1.695156
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
# H: 22 / 30 : Minimum distance = 1.752703
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
# H: 27 / 30 : Minimum distance = 1.632375
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999999
# H: 30 / 30 : Minimum distance = 1.600361Total Box Mass: 1489.34 g
# Computed ideal box length for dens 1.500000 is 9.976255 Angstrom
# C: 98 / 100 : Minimum distance = 1.846862
#  Setting new minimum interatomic distance after many failed placements: 1.79
# O: 3 / 16 : Minimum distance = 1.792429224
#  Setting new minimum interatomic distance after many failed placements: 1.78
# O: 8 / 16 : Minimum distance = 1.788446
#  Setting new minimum interatomic distance after many failed placements: 1.77
# O: 9 / 16 : Minimum distance = 1.777600
#  Setting new minimum interatomic distance after many failed placements: 1.76
# O: 13 / 16 : Minimum distance = 1.791218
#  Setting new minimum interatomic distance after many failed placements: 1.75
# O: 14 / 16 : Minimum distance = 1.860850
#  Setting new minimum interatomic distance after many failed placements: 1.74
# O: 16 / 16 : Minimum distance = 1.779136
#  Setting new minimum interatomic distance after many failed placements: 1.73
# H: 5 / 32 : Minimum distance = 1.731208
#  Setting new minimum interatomic distance after many failed placements: 1.72
#
#  Setting new minimum interatomic distance after many failed placements: 1.71
# H: 6 / 32 : Minimum distance = 1.724736
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 12 / 32 : Minimum distance = 1.715954
#  Setting new minimum interatomic distance after many failed placements: 1.69
# H: 14 / 32 : Minimum distance = 1.747873
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 15 / 32 : Minimum distance = 1.729014
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 16 / 32 : Minimum distance = 1.722868
#  Setting new minimum interatomic distance after many failed placements: 1.66
# H: 19 / 32 : Minimum distance = 1.676308
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 20 / 32 : Minimum distance = 1.738844
#  Setting new minimum interatomic distance after many failed placements: 1.64
# H: 23 / 32 : Minimum distance = 1.650782
#  Setting new minimum interatomic distance after many failed placements: 1.63
#
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
# H: 26 / 32 : Minimum distance = 1.623964
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
# H: 27 / 32 : Minimum distance = 1.674753
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.5899999999999999
# H: 29 / 32 : Minimum distance = 1.610388
#  Setting new minimum interatomic distance after many failed placements: 1.5799999999999998
# H: 30 / 32 : Minimum distance = 1.617985
#  Setting new minimum interatomic distance after many failed placements: 1.5699999999999998
# H: 32 / 32 : Minimum distance = 1.608331Total Box Mass: 1507.3549999999998 g
# Computed ideal box length for dens 1.500000 is 10.016318 Angstrom
# O: 3 / 17 : Minimum distance = 1.811605723
#  Setting new minimum interatomic distance after many failed placements: 1.79
# O: 8 / 17 : Minimum distance = 1.857692
#  Setting new minimum interatomic distance after many failed placements: 1.78
#
#  Setting new minimum interatomic distance after many failed placements: 1.77
# O: 10 / 17 : Minimum distance = 1.792405
#  Setting new minimum interatomic distance after many failed placements: 1.76
# O: 13 / 17 : Minimum distance = 1.764569
#  Setting new minimum interatomic distance after many failed placements: 1.75
# H: 2 / 34 : Minimum distance = 1.7659120
#  Setting new minimum interatomic distance after many failed placements: 1.74
# H: 3 / 34 : Minimum distance = 1.742562
#  Setting new minimum interatomic distance after many failed placements: 1.73
# H: 5 / 34 : Minimum distance = 1.777721
#  Setting new minimum interatomic distance after many failed placements: 1.72
#
#  Setting new minimum interatomic distance after many failed placements: 1.71
# H: 8 / 34 : Minimum distance = 1.710962
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 9 / 34 : Minimum distance = 1.725952
#  Setting new minimum interatomic distance after many failed placements: 1.69
# H: 10 / 34 : Minimum distance = 1.693005
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 12 / 34 : Minimum distance = 1.687754
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 13 / 34 : Minimum distance = 1.688078
#  Setting new minimum interatomic distance after many failed placements: 1.66
# H: 14 / 34 : Minimum distance = 1.660241
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 16 / 34 : Minimum distance = 1.691270
#  Setting new minimum interatomic distance after many failed placements: 1.64
# H: 17 / 34 : Minimum distance = 1.648344
#  Setting new minimum interatomic distance after many failed placements: 1.63
# H: 19 / 34 : Minimum distance = 1.644950
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
# H: 21 / 34 : Minimum distance = 1.621098
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999999
# H: 23 / 34 : Minimum distance = 1.713259
#  Setting new minimum interatomic distance after many failed placements: 1.5899999999999999
# H: 26 / 34 : Minimum distance = 1.609363
#  Setting new minimum interatomic distance after many failed placements: 1.5799999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.5699999999999998
# H: 32 / 34 : Minimum distance = 1.570483
#  Setting new minimum interatomic distance after many failed placements: 1.5599999999999998
# H: 34 / 34 : Minimum distance = 1.605337Total Box Mass: 1525.37 g
# Computed ideal box length for dens 1.500000 is 10.056063 Angstrom
# O: 2 / 18 : Minimum distance = 1.811269317
#  Setting new minimum interatomic distance after many failed placements: 1.79
# O: 9 / 18 : Minimum distance = 1.840471
#  Setting new minimum interatomic distance after many failed placements: 1.78
# O: 13 / 18 : Minimum distance = 1.788986
#  Setting new minimum interatomic distance after many failed placements: 1.77
#
#  Setting new minimum interatomic distance after many failed placements: 1.76
#
#  Setting new minimum interatomic distance after many failed placements: 1.75
# O: 16 / 18 : Minimum distance = 1.782453
#  Setting new minimum interatomic distance after many failed placements: 1.74
# H: 2 / 36 : Minimum distance = 1.7408660
#  Setting new minimum interatomic distance after many failed placements: 1.73
# H: 5 / 36 : Minimum distance = 1.755952
#  Setting new minimum interatomic distance after many failed placements: 1.72
# H: 9 / 36 : Minimum distance = 1.726139
#  Setting new minimum interatomic distance after many failed placements: 1.71
# H: 11 / 36 : Minimum distance = 1.787289
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 12 / 36 : Minimum distance = 1.707647
#  Setting new minimum interatomic distance after many failed placements: 1.69
# H: 15 / 36 : Minimum distance = 1.703942
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 17 / 36 : Minimum distance = 1.700103
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 18 / 36 : Minimum distance = 1.692802
#  Setting new minimum interatomic distance after many failed placements: 1.66
# H: 19 / 36 : Minimum distance = 1.660575
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 20 / 36 : Minimum distance = 1.716308
#  Setting new minimum interatomic distance after many failed placements: 1.64
# H: 21 / 36 : Minimum distance = 1.644355
#  Setting new minimum interatomic distance after many failed placements: 1.63
#
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
# H: 24 / 36 : Minimum distance = 1.610270
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999999
# H: 27 / 36 : Minimum distance = 1.652713
#  Setting new minimum interatomic distance after many failed placements: 1.5899999999999999
# H: 29 / 36 : Minimum distance = 1.595308
#  Setting new minimum interatomic distance after many failed placements: 1.5799999999999998
# H: 32 / 36 : Minimum distance = 1.616760
#  Setting new minimum interatomic distance after many failed placements: 1.5699999999999998
# H: 33 / 36 : Minimum distance = 1.650822
#  Setting new minimum interatomic distance after many failed placements: 1.5599999999999998
# H: 36 / 36 : Minimum distance = 1.593172Total Box Mass: 1543.385 g
# Computed ideal box length for dens 1.500000 is 10.095496 Angstrom
# O: 8 / 19 : Minimum distance = 1.860228605
#  Setting new minimum interatomic distance after many failed placements: 1.79
# O: 13 / 19 : Minimum distance = 1.875223
#  Setting new minimum interatomic distance after many failed placements: 1.78
# O: 16 / 19 : Minimum distance = 1.828837
#  Setting new minimum interatomic distance after many failed placements: 1.77
# O: 18 / 19 : Minimum distance = 1.781885
#  Setting new minimum interatomic distance after many failed placements: 1.76
# O: 19 / 19 : Minimum distance = 1.770645
#  Setting new minimum interatomic distance after many failed placements: 1.75
#
#  Setting new minimum interatomic distance after many failed placements: 1.74
# H: 3 / 38 : Minimum distance = 1.780034
#  Setting new minimum interatomic distance after many failed placements: 1.73
# H: 5 / 38 : Minimum distance = 1.785285
#  Setting new minimum interatomic distance after many failed placements: 1.72
# H: 7 / 38 : Minimum distance = 1.731340
#  Setting new minimum interatomic distance after many failed placements: 1.71
#
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 8 / 38 : Minimum distance = 1.709363
#  Setting new minimum interatomic distance after many failed placements: 1.69
# H: 9 / 38 : Minimum distance = 1.722197
#  Setting new minimum interatomic distance after many failed placements: 1.68
#
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 10 / 38 : Minimum distance = 1.732986
#  Setting new minimum interatomic distance after many failed placements: 1.66
# H: 13 / 38 : Minimum distance = 1.676261
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 18 / 38 : Minimum distance = 1.706505
#  Setting new minimum interatomic distance after many failed placements: 1.64
#
#  Setting new minimum interatomic distance after many failed placements: 1.63
# H: 19 / 38 : Minimum distance = 1.643155
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
# H: 22 / 38 : Minimum distance = 1.642380
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
# H: 23 / 38 : Minimum distance = 1.616387
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999999
# H: 25 / 38 : Minimum distance = 1.680830
#  Setting new minimum interatomic distance after many failed placements: 1.5899999999999999
# H: 27 / 38 : Minimum distance = 1.599476
#  Setting new minimum interatomic distance after many failed placements: 1.5799999999999998
# H: 31 / 38 : Minimum distance = 1.619046
#  Setting new minimum interatomic distance after many failed placements: 1.5699999999999998
# H: 36 / 38 : Minimum distance = 1.582547
#  Setting new minimum interatomic distance after many failed placements: 1.5599999999999998
# H: 38 / 38 : Minimum distance = 1.609637Total Box Mass: 1561.3999999999999 g
# Computed ideal box length for dens 1.500000 is 10.134624 Angstrom
# O: 2 / 20 : Minimum distance = 1.882550337
#  Setting new minimum interatomic distance after many failed placements: 1.79
# O: 5 / 20 : Minimum distance = 1.880287
#  Setting new minimum interatomic distance after many failed placements: 1.78
# O: 12 / 20 : Minimum distance = 1.850940
#  Setting new minimum interatomic distance after many failed placements: 1.77
# O: 16 / 20 : Minimum distance = 1.886781
#  Setting new minimum interatomic distance after many failed placements: 1.76
# O: 19 / 20 : Minimum distance = 1.793212
#  Setting new minimum interatomic distance after many failed placements: 1.75
# O: 20 / 20 : Minimum distance = 1.757202
#  Setting new minimum interatomic distance after many failed placements: 1.74
# H: 3 / 40 : Minimum distance = 1.773952
#  Setting new minimum interatomic distance after many failed placements: 1.73
# H: 6 / 40 : Minimum distance = 1.772703
#  Setting new minimum interatomic distance after many failed placements: 1.72
# H: 7 / 40 : Minimum distance = 1.749996
#  Setting new minimum interatomic distance after many failed placements: 1.71
#
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 8 / 40 : Minimum distance = 1.734258
#  Setting new minimum interatomic distance after many failed placements: 1.69
# H: 12 / 40 : Minimum distance = 1.695695
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 13 / 40 : Minimum distance = 1.681008
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 14 / 40 : Minimum distance = 1.729028
#  Setting new minimum interatomic distance after many failed placements: 1.66
# H: 17 / 40 : Minimum distance = 1.689050
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 20 / 40 : Minimum distance = 1.707018
#  Setting new minimum interatomic distance after many failed placements: 1.64
# H: 23 / 40 : Minimum distance = 1.663232
#  Setting new minimum interatomic distance after many failed placements: 1.63
# H: 26 / 40 : Minimum distance = 1.639786
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
# H: 27 / 40 : Minimum distance = 1.660583
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
# H: 31 / 40 : Minimum distance = 1.618008
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999999
# H: 33 / 40 : Minimum distance = 1.624066
#  Setting new minimum interatomic distance after many failed placements: 1.5899999999999999
# H: 34 / 40 : Minimum distance = 1.676815
#  Setting new minimum interatomic distance after many failed placements: 1.5799999999999998
# H: 39 / 40 : Minimum distance = 1.663481
#  Setting new minimum interatomic distance after many failed placements: 1.5699999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.5599999999999998
# H: 40 / 40 : Minimum distance = 1.580203Total Box Mass: 1579.415 g
# Computed ideal box length for dens 1.500000 is 10.173452 Angstrom
# O: 10 / 21 : Minimum distance = 1.81826925
#  Setting new minimum interatomic distance after many failed placements: 1.79
# O: 16 / 21 : Minimum distance = 1.874927
#  Setting new minimum interatomic distance after many failed placements: 1.78
# O: 18 / 21 : Minimum distance = 1.848262
#  Setting new minimum interatomic distance after many failed placements: 1.77
# O: 21 / 21 : Minimum distance = 1.778704
#  Setting new minimum interatomic distance after many failed placements: 1.76
# H: 2 / 42 : Minimum distance = 1.787892
#  Setting new minimum interatomic distance after many failed placements: 1.75
# H: 4 / 42 : Minimum distance = 1.753761
#  Setting new minimum interatomic distance after many failed placements: 1.74
# H: 5 / 42 : Minimum distance = 1.764953
#  Setting new minimum interatomic distance after many failed placements: 1.73
# H: 7 / 42 : Minimum distance = 1.735357
#  Setting new minimum interatomic distance after many failed placements: 1.72
# H: 8 / 42 : Minimum distance = 1.748172
#  Setting new minimum interatomic distance after many failed placements: 1.71
#
#  Setting new minimum interatomic distance after many failed placements: 1.7
# H: 9 / 42 : Minimum distance = 1.757441
#  Setting new minimum interatomic distance after many failed placements: 1.69
# H: 11 / 42 : Minimum distance = 1.733135
#  Setting new minimum interatomic distance after many failed placements: 1.68
# H: 13 / 42 : Minimum distance = 1.696728
#  Setting new minimum interatomic distance after many failed placements: 1.67
# H: 16 / 42 : Minimum distance = 1.685088
#  Setting new minimum interatomic distance after many failed placements: 1.66
# H: 17 / 42 : Minimum distance = 1.686971
#  Setting new minimum interatomic distance after many failed placements: 1.65
# H: 19 / 42 : Minimum distance = 1.667524
#  Setting new minimum interatomic distance after many failed placements: 1.64
# H: 22 / 42 : Minimum distance = 1.641451
#  Setting new minimum interatomic distance after many failed placements: 1.63
# H: 24 / 42 : Minimum distance = 1.643060
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
# H: 25 / 42 : Minimum distance = 1.620856
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
# H: 27 / 42 : Minimum distance = 1.637801
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999999
# H: 31 / 42 : Minimum distance = 1.617956
#  Setting new minimum interatomic distance after many failed placements: 1.5899999999999999
# H: 35 / 42 : Minimum distance = 1.649672
#  Setting new minimum interatomic distance after many failed placements: 1.5799999999999998
# H: 39 / 42 : Minimum distance = 1.594712
#  Setting new minimum interatomic distance after many failed placements: 1.5699999999999998
# H: 42 / 42 : Minimum distance = 1.572615Total Box Mass: 1597.43 g
# Computed ideal box length for dens 1.500000 is 10.211986 Angstrom
# O: 7 / 22 : Minimum distance = 1.889376818
#  Setting new minimum interatomic distance after many failed placements: 1.79
# O: 9 / 22 : Minimum distance = 1.944099
#  Setting new minimum interatomic distance after many failed placements: 1.78
# O: 12 / 22 : Minimum distance = 1.808174
# ...
#
#  Setting new minimum interatomic distance after many failed placements: 1.4999999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.4899999999999998
# O: 16 / 23 : Minimum distance = 1.493226
#  Setting new minimum interatomic distance after many failed placements: 1.4799999999999998
# O: 17 / 23 : Minimum distance = 1.531843
#  Setting new minimum interatomic distance after many failed placements: 1.4699999999999998
# O: 18 / 23 : Minimum distance = 1.473894
#  Setting new minimum interatomic distance after many failed placements: 1.4599999999999997
# O: 21 / 23 : Minimum distance = 1.537751
#  Setting new minimum interatomic distance after many failed placements: 1.4499999999999997
# O: 23 / 23 : Minimum distance = 1.466374
#  Setting new minimum interatomic distance after many failed placements: 1.4399999999999997
# H: 1 / 46 : Minimum distance = 1.451913
#  Setting new minimum interatomic distance after many failed placements: 1.4299999999999997
# H: 2 / 46 : Minimum distance = 1.430275
#  Setting new minimum interatomic distance after many failed placements: 1.4199999999999997
# H: 6 / 46 : Minimum distance = 1.436168
#  Setting new minimum interatomic distance after many failed placements: 1.4099999999999997
# H: 9 / 46 : Minimum distance = 1.440681
#  Setting new minimum interatomic distance after many failed placements: 1.3999999999999997
# H: 13 / 46 : Minimum distance = 1.403050
#  Setting new minimum interatomic distance after many failed placements: 1.3899999999999997
# H: 15 / 46 : Minimum distance = 1.404009
#  Setting new minimum interatomic distance after many failed placements: 1.3799999999999997
# H: 20 / 46 : Minimum distance = 1.430994
#  Setting new minimum interatomic distance after many failed placements: 1.3699999999999997
# H: 22 / 46 : Minimum distance = 1.405061
#  Setting new minimum interatomic distance after many failed placements: 1.3599999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.3499999999999996
# H: 26 / 46 : Minimum distance = 1.369013
#  Setting new minimum interatomic distance after many failed placements: 1.3399999999999996
# H: 28 / 46 : Minimum distance = 1.347177
#  Setting new minimum interatomic distance after many failed placements: 1.3299999999999996
# H: 31 / 46 : Minimum distance = 1.331281
#  Setting new minimum interatomic distance after many failed placements: 1.3199999999999996
#
#  Setting new minimum interatomic distance after many failed placements: 1.3099999999999996
# H: 34 / 46 : Minimum distance = 1.312655
#  Setting new minimum interatomic distance after many failed placements: 1.2999999999999996
# H: 38 / 46 : Minimum distance = 1.309746
#  Setting new minimum interatomic distance after many failed placements: 1.2899999999999996
# H: 41 / 46 : Minimum distance = 1.328101
#  Setting new minimum interatomic distance after many failed placements: 1.2799999999999996
# H: 46 / 46 : Minimum distance = 1.282965Total Box Mass: 1633.46 g
# Computed ideal box length for dens 2.500000 is 8.677398 Angstrom
# C: 69 / 100 : Minimum distance = 1.887609
#  Setting new minimum interatomic distance after many failed placements: 1.79
# C: 71 / 100 : Minimum distance = 1.798215
#  Setting new minimum interatomic distance after many failed placements: 1.78
# C: 72 / 100 : Minimum distance = 1.789710
#  Setting new minimum interatomic distance after many failed placements: 1.77
# C: 75 / 100 : Minimum distance = 1.921380
#  Setting new minimum interatomic distance after many failed placements: 1.76
# C: 77 / 100 : Minimum distance = 1.789275
#  Setting new minimum interatomic distance after many failed placements: 1.75
# C: 79 / 100 : Minimum distance = 1.754645
#  Setting new minimum interatomic distance after many failed placements: 1.74
# C: 81 / 100 : Minimum distance = 1.834495
#  Setting new minimum interatomic distance after many failed placements: 1.73
# C: 83 / 100 : Minimum distance = 1.754580
#  Setting new minimum interatomic distance after many failed placements: 1.72
# C: 84 / 100 : Minimum distance = 1.743343
#  Setting new minimum interatomic distance after many failed placements: 1.71
# C: 85 / 100 : Minimum distance = 1.716236
#  Setting new minimum interatomic distance after many failed placements: 1.7
#
#  Setting new minimum interatomic distance after many failed placements: 1.69
#
#  Setting new minimum interatomic distance after many failed placements: 1.68
# C: 86 / 100 : Minimum distance = 1.694486
#  Setting new minimum interatomic distance after many failed placements: 1.67
# C: 87 / 100 : Minimum distance = 1.671553
#  Setting new minimum interatomic distance after many failed placements: 1.66
#
#  Setting new minimum interatomic distance after many failed placements: 1.65
#
#  Setting new minimum interatomic distance after many failed placements: 1.64
#
#  Setting new minimum interatomic distance after many failed placements: 1.63
#
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
# C: 90 / 100 : Minimum distance = 1.644237
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
# C: 94 / 100 : Minimum distance = 1.617220
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.5899999999999999
# C: 98 / 100 : Minimum distance = 1.613851
#  Setting new minimum interatomic distance after many failed placements: 1.5799999999999998
# O: 2 / 24 : Minimum distance = 1.597024152
#  Setting new minimum interatomic distance after many failed placements: 1.5699999999999998
# O: 4 / 24 : Minimum distance = 1.577146
#  Setting new minimum interatomic distance after many failed placements: 1.5599999999999998
# O: 6 / 24 : Minimum distance = 1.566228
#  Setting new minimum interatomic distance after many failed placements: 1.5499999999999998
# O: 7 / 24 : Minimum distance = 1.590341
#  Setting new minimum interatomic distance after many failed placements: 1.5399999999999998
# O: 8 / 24 : Minimum distance = 1.557214
#  Setting new minimum interatomic distance after many failed placements: 1.5299999999999998
# O: 10 / 24 : Minimum distance = 1.537252
#  Setting new minimum interatomic distance after many failed placements: 1.5199999999999998
# O: 12 / 24 : Minimum distance = 1.523496
#  Setting new minimum interatomic distance after many failed placements: 1.5099999999999998
# O: 14 / 24 : Minimum distance = 1.531785
#  Setting new minimum interatomic distance after many failed placements: 1.4999999999999998
# O: 17 / 24 : Minimum distance = 1.518169
#  Setting new minimum interatomic distance after many failed placements: 1.4899999999999998
# O: 19 / 24 : Minimum distance = 1.503157
#  Setting new minimum interatomic distance after many failed placements: 1.4799999999999998
# O: 21 / 24 : Minimum distance = 1.480915
#  Setting new minimum interatomic distance after many failed placements: 1.4699999999999998
# O: 22 / 24 : Minimum distance = 1.495598
#  Setting new minimum interatomic distance after many failed placements: 1.4599999999999997
# O: 24 / 24 : Minimum distance = 1.463516
#  Setting new minimum interatomic distance after many failed placements: 1.4499999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.4399999999999997
# H: 3 / 48 : Minimum distance = 1.462762
#  Setting new minimum interatomic distance after many failed placements: 1.4299999999999997
# H: 4 / 48 : Minimum distance = 1.439628
#  Setting new minimum interatomic distance after many failed placements: 1.4199999999999997
# H: 9 / 48 : Minimum distance = 1.440514
#  Setting new minimum interatomic distance after many failed placements: 1.4099999999999997
# H: 10 / 48 : Minimum distance = 1.462876
#  Setting new minimum interatomic distance after many failed placements: 1.3999999999999997
# H: 11 / 48 : Minimum distance = 1.403328
#  Setting new minimum interatomic distance after many failed placements: 1.3899999999999997
# H: 14 / 48 : Minimum distance = 1.422113
#  Setting new minimum interatomic distance after many failed placements: 1.3799999999999997
# H: 15 / 48 : Minimum distance = 1.389560
#  Setting new minimum interatomic distance after many failed placements: 1.3699999999999997
# H: 18 / 48 : Minimum distance = 1.462206
#  Setting new minimum interatomic distance after many failed placements: 1.3599999999999997
# H: 22 / 48 : Minimum distance = 1.381407
#  Setting new minimum interatomic distance after many failed placements: 1.3499999999999996
# H: 25 / 48 : Minimum distance = 1.360309
#  Setting new minimum interatomic distance after many failed placements: 1.3399999999999996
# H: 29 / 48 : Minimum distance = 1.391385
#  Setting new minimum interatomic distance after many failed placements: 1.3299999999999996
# H: 31 / 48 : Minimum distance = 1.349816
#  Setting new minimum interatomic distance after many failed placements: 1.3199999999999996
# H: 35 / 48 : Minimum distance = 1.324225
#  Setting new minimum interatomic distance after many failed placements: 1.3099999999999996
# H: 38 / 48 : Minimum distance = 1.345090
#  Setting new minimum interatomic distance after many failed placements: 1.2999999999999996
# H: 42 / 48 : Minimum distance = 1.303331
#  Setting new minimum interatomic distance after many failed placements: 1.2899999999999996
# H: 46 / 48 : Minimum distance = 1.297290
#  Setting new minimum interatomic distance after many failed placements: 1.2799999999999996
# H: 48 / 48 : Minimum distance = 1.332094Total Box Mass: 1651.475 g
# Computed ideal box length for dens 2.500000 is 8.709181 Angstrom
# C: 69 / 100 : Minimum distance = 1.818969
#  Setting new minimum interatomic distance after many failed placements: 1.79
# C: 71 / 100 : Minimum distance = 1.809549
#  Setting new minimum interatomic distance after many failed placements: 1.78
# C: 72 / 100 : Minimum distance = 1.792834
#  Setting new minimum interatomic distance after many failed placements: 1.77
# C: 73 / 100 : Minimum distance = 1.810836
#  Setting new minimum interatomic distance after many failed placements: 1.76
# C: 75 / 100 : Minimum distance = 1.774128
#  Setting new minimum interatomic distance after many failed placements: 1.75
# C: 76 / 100 : Minimum distance = 1.790166
#  Setting new minimum interatomic distance after many failed placements: 1.74
# C: 79 / 100 : Minimum distance = 1.743333
#  Setting new minimum interatomic distance after many failed placements: 1.73
# C: 80 / 100 : Minimum distance = 1.760145
#  Setting new minimum interatomic distance after many failed placements: 1.72
#
#  Setting new minimum interatomic distance after many failed placements: 1.71
# C: 82 / 100 : Minimum distance = 1.726268
#  Setting new minimum interatomic distance after many failed placements: 1.7
# C: 83 / 100 : Minimum distance = 1.707689
#  Setting new minimum interatomic distance after many failed placements: 1.69
# C: 85 / 100 : Minimum distance = 1.706396
#  Setting new minimum interatomic distance after many failed placements: 1.68
#
#  Setting new minimum interatomic distance after many failed placements: 1.67
# C: 87 / 100 : Minimum distance = 1.678344
#  Setting new minimum interatomic distance after many failed placements: 1.66
# C: 92 / 100 : Minimum distance = 1.671670
#  Setting new minimum interatomic distance after many failed placements: 1.65
# C: 94 / 100 : Minimum distance = 1.650912
#  Setting new minimum interatomic distance after many failed placements: 1.64
# C: 96 / 100 : Minimum distance = 1.662053
#  Setting new minimum interatomic distance after many failed placements: 1.63
# C: 97 / 100 : Minimum distance = 1.663379
#  Setting new minimum interatomic distance after many failed placements: 1.6199999999999999
# C: 100 / 100 : Minimum distance = 1.696129
#  Setting new minimum interatomic distance after many failed placements: 1.6099999999999999
# O: 1 / 25 : Minimum distance = 1.629243
#  Setting new minimum interatomic distance after many failed placements: 1.5999999999999999
#
#  Setting new minimum interatomic distance after many failed placements: 1.5899999999999999
# O: 3 / 25 : Minimum distance = 1.595572
#  Setting new minimum interatomic distance after many failed placements: 1.5799999999999998
# O: 4 / 25 : Minimum distance = 1.606126
#  Setting new minimum interatomic distance after many failed placements: 1.5699999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.5599999999999998
# O: 6 / 25 : Minimum distance = 1.572337
#  Setting new minimum interatomic distance after many failed placements: 1.5499999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.5399999999999998
# O: 8 / 25 : Minimum distance = 1.576748
#  Setting new minimum interatomic distance after many failed placements: 1.5299999999999998
# O: 10 / 25 : Minimum distance = 1.566075
#  Setting new minimum interatomic distance after many failed placements: 1.5199999999999998
# O: 13 / 25 : Minimum distance = 1.538600
#  Setting new minimum interatomic distance after many failed placements: 1.5099999999999998
# O: 15 / 25 : Minimum distance = 1.609525
#  Setting new minimum interatomic distance after many failed placements: 1.4999999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.4899999999999998
# O: 17 / 25 : Minimum distance = 1.520059
#  Setting new minimum interatomic distance after many failed placements: 1.4799999999999998
#
#  Setting new minimum interatomic distance after many failed placements: 1.4699999999999998
# O: 19 / 25 : Minimum distance = 1.531707
#  Setting new minimum interatomic distance after many failed placements: 1.4599999999999997
# O: 21 / 25 : Minimum distance = 1.476803
#  Setting new minimum interatomic distance after many failed placements: 1.4499999999999997
# O: 22 / 25 : Minimum distance = 1.454081
#  Setting new minimum interatomic distance after many failed placements: 1.4399999999999997
# H: 3 / 50 : Minimum distance = 1.4559508
#  Setting new minimum interatomic distance after many failed placements: 1.4299999999999997
# H: 5 / 50 : Minimum distance = 1.472910
#  Setting new minimum interatomic distance after many failed placements: 1.4199999999999997
# H: 9 / 50 : Minimum distance = 1.487295
#  Setting new minimum interatomic distance after many failed placements: 1.4099999999999997
#
#  Setting new minimum interatomic distance after many failed placements: 1.3999999999999997
# H: 12 / 50 : Minimum distance = 1.459765
#  Setting new minimum interatomic distance after many failed placements: 1.3899999999999997
# H: 13 / 50 : Minimum distance = 1.414973
#  Setting new minimum interatomic distance after many failed placements: 1.3799999999999997
# H: 15 / 50 : Minimum distance = 1.382063
#  Setting new minimum interatomic distance after many failed placements: 1.3699999999999997
# H: 16 / 50 : Minimum distance = 1.400915
#  Setting new minimum interatomic distance after many failed placements: 1.3599999999999997
# H: 21 / 50 : Minimum distance = 1.399722
#  Setting new minimum interatomic distance after many failed placements: 1.3499999999999996
# H: 24 / 50 : Minimum distance = 1.358078
#  Setting new minimum interatomic distance after many failed placements: 1.3399999999999996
# H: 28 / 50 : Minimum distance = 1.459659
#  Setting new minimum interatomic distance after many failed placements: 1.3299999999999996
# H: 30 / 50 : Minimum distance = 1.355735
#  Setting new minimum interatomic distance after many failed placements: 1.3199999999999996
# H: 34 / 50 : Minimum distance = 1.321669
#  Setting new minimum interatomic distance after many failed placements: 1.3099999999999996
# H: 36 / 50 : Minimum distance = 1.318440
#  Setting new minimum interatomic distance after many failed placements: 1.2999999999999996
# H: 38 / 50 : Minimum distance = 1.302112
#  Setting new minimum interatomic distance after many failed placements: 1.2899999999999996
# H: 42 / 50 : Minimum distance = 1.347051
#  Setting new minimum interatomic distance after many failed placements: 1.2799999999999996
# H: 44 / 50 : Minimum distance = 1.300834
#  Setting new minimum interatomic distance after many failed placements: 1.2699999999999996
# H: 50 / 50 : Minimum distance = 1.300905

# %%
# Out:
# [[0 1 2]
#  [3 4 5]
#  [6 7 8]]
# [['A' 'B' 'C']]

# %%
# Out:
# array([['A', '0', '1', '2'],
#        ['B', '3', '4', '5'],
#        ['C', '6', '7', '8']], dtype='<U21')
